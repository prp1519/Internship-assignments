# %% [markdown]
# <a href="https://colab.research.google.com/github/prp1519/Internship-assignments/blob/main/falsea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np

# %%
df= pd.read_csv('doccsv.csv')

# %%
df
# Out:
#                                                 title  \
# 0   Majority of Turkish people do not trust NATO: ...
# 1        Fissures become apparent in PML N leadership
# 2   Macron wants to meet ErdoÄŸan ahead of NATO su...
# 3   Former SAPM Zulfi Bukhari returns back to Paki...
# 4   Ethiopia Tigray conflict: Rebels build on capt...
# 5   RTHK: How authorities cracked down on Hong Kon...
# 6   Pakistan Rolls Out First Locally Overhauled JF...
# 7   Pakistan Navy Tests Land-Based Anti-Ship Missi...
# 8   Press Release: Pakistan Air Force Conducts Haw...
# 9   Regular Press Conference of the Ministry of Na...
# 10  Wang Yi: China-U.S. relationship is 'at an imp...
# 11  National security agencies warn of 5G network ...
# 12  Biden orders wide cybersecurity changes for go...
# 13  Air Force general busts myth that enemies alwa...
# 14  Special Operations team in Pacific will confro...
# 15         US Army emphasizes ‘information advantage’
# 16  Early Risk Reduction For The Bomber Of The Future
# 17  US Talks With Israel About Buying More Iron Do...
# 18  SecDef Austin Takes Personal Charge of DoD Chi...
#
#                                              firstone  \
# 0   A whopping majority of Turkish people do not t...
# 1   A few days ago, PML-N President and Opposition...
# 2   French President Emmanuel Macron said Thursday...
# 3   Former special assistant to prime minister (SA...
# 4   The rebels have now entered the town of Shire,...
# 5   The critically acclaimed Radio Television Hong...
# 6   On 26 September, the Pakistan Air Force (PAF) ...
# 7   On 05 November 2019, the Pakistan Navy (PN) an...
# 8   The Pakistan Air Force conducted a command lev...
# 9   In the new year, we hope that the US side coul...
# 10  The relationship between China and the United ...
# 11  A group of top U.S. national security agencies...
# 12  Following government cyber breaches, the Biden...
# 13  A top Air Force general wants to dispel the co...
# 14  U.S. Special Operations Command created a task...
# 15  The U.S. Army will soon make “information adva...
# 16  Northrop Grumman uses its Highly Immersive Vir...
# 17   The performance of the Israeli Iron Dome air ...
# 18   In a clear sign that China really is the Bide...
#
#                                              firsttwo  \
# 0   A whopping majority of Turkish people do not t...
# 1   A few days ago, PML-N President and Opposition...
# 2   French President Emmanuel Macron said Thursday...
# 3   Former special assistant to prime minister (SA...
# 4   The rebels have now entered the town of Shire,...
# 5   The critically acclaimed Radio Television Hong...
# 6   On 26 September, the Pakistan Air Force (PAF) ...
# 7   On 05 November 2019, the Pakistan Navy (PN) an...
# 8   The Pakistan Air Force conducted a command lev...
# 9   In the new year, we hope that the US side coul...
# 10  The relationship between China and the United ...
# 11  A group of top U.S. national security agencies...
# 12  Following government cyber breaches, the Biden...
# 13  A top Air Force general wants to dispel the co...
# 14  U.S. Special Operations Command created a task...
# 15  The U.S. Army will soon make “information adva...
# 16  Northrop Grumman uses its Highly Immersive Vir...
# 17  The performance of the Israeli Iron Dome air d...
# 18  In a clear sign that China really is the Biden...
#
#                                            firstthree  \
# 0   A whopping majority of Turkish people do not t...
# 1   A few days ago, PML-N President and Opposition...
# 2   French President Emmanuel Macron said Thursday...
# 3   Former special assistant to prime minister (SA...
# 4   The rebels have now entered the town of Shire,...
# 5   The critically acclaimed Radio Television Hong...
# 6   On 26 September, the Pakistan Air Force (PAF) ...
# 7   On 05 November 2019, the Pakistan Navy (PN) an...
# 8   The Pakistan Air Force conducted a command lev...
# 9   In the new year, we hope that the US side coul...
# 10  The relationship between China and the United ...
# 11  A group of top U.S. national security agencies...
# 12  Following government cyber breaches, the Biden...
# 13   A top Air Force general wants to dispel the c...
# 14  U.S. Special Operations Command created a task...
# 15  The U.S. Army will soon make “information adva...
# 16  Northrop Grumman uses its Highly Immersive Vir...
# 17  The performance of the Israeli Iron Dome air d...
# 18  In a clear sign that China really is the Biden...
#
#                                              first250  \
# 0   A whopping majority of Turkish people do not t...
# 1   A few days ago, PML-N President and Opposition...
# 2   French President Emmanuel Macron said Thursday...
# 3   Former special assistant to prime minister (SA...
# 4   The rebels have now entered the town of Shire,...
# 5   The critically acclaimed Radio Television Hong...
# 6   On 26 September, the Pakistan Air Force (PAF) ...
# 7   On 05 November 2019, the Pakistan Navy (PN) an...
# 8   Islamabad 29 November, 2019:- The Pakistan Air...
# 9   In the new year, we hope that the US side coul...
# 10  The relationship between China and the United ...
# 11  A group of top U.S. national security agencies...
# 12  Following government cyber breaches, the Biden...
# 13  A top Air Force general wants to dispel the co...
# 14  U.S. Special Operations Command created a task...
# 15  The U.S. Army will soon make “information adva...
# 16  Northrop Grumman uses its Highly Immersive Vir...
# 17  The performance of the Israeli Iron Dome air d...
# 18  In a clear sign that China really is the Biden...
#
#                                               lastone  \
# 0    The alliance is based on the core principle o...
# 1    But he had to face embarrassment at the hands...
# 2    We must ensure that no misunderstanding comes...
# 3   is ensured that the new alignment is free from...
# 4    The UN has said there was a situation of fami...
# 5   "2019 was a turning point and [the crackdown] ...
# 6   Tomislav Mesaric. â€œPride of Pakistanâ€. Air...
# 7    According to the Pakistan Ministry of Defence...
# 8    If your company would like to request Quwa to...
# 9   Despite challenges and difficulties, they will...
# 10  The Chinese foreign minister urged to work tog...
# 11  These vulnerabilities could then later be expl...
# 12  Mark Warner, D-Virginia, chairman of the Intel...
# 13  “We’ll need capabilities to streamline the spe...
# 14   This is something that U.S. Cyber Command and...
# 15  Given how quickly the information domain evolv...
# 16  we have innovative applications of digital too...
# 17  The largest of the four categories is called “...
# 18  With today’s directive, the task force is no m...
#
#                                               lasttwo  \
# 0    Turkey is important for NATO, but NATO is als...
# 1    As a matter of principle, Shehbaz Sharif’s in...
# 2    And they will remain so. We must ensure that ...
# 3   Rawalpindi Commissioner Syed Gulzar Hussain Sh...
# 4   State department spokesperson Ned Price said t...
# 5   Analysts say the changes to RTHK are yet anoth...
# 6   The which will be the JF-17â€™s most extensive...
# 7   Having acquired long-range subsonic ASCMs, the...
# 8    Quwa does not grant rights to reproduce or us...
# 9   They will adopt a holistic approach to nationa...
# 10  Oxen are known for their diligence and strengt...
# 11  Flaws or malware inserted early in the develop...
# 12  Congress is going to have to step up and do mo...
# 13  Culture also must change to accept automation,...
# 14  “This is not going to be episodic. This is som...
# 15  The Army in 2017 released the to integrate cyb...
# 16  What we have on the production line now are so...
# 17  In this brief video interview, Northrop Grumma...
# 18  “The initiatives I am putting forward today ar...
#
#                                             lastthree  \
# 0    Despite this fluctuating relationship, NATO c...
# 1   At this juncture the question is not whether t...
# 2    During the visit, parth said Turkey and Franc...
# 3    The Punjab government said that former commis...
# 4    On Tuesday, senior US state department offici...
# 5     "Many of them think that RTHK should not bit...
# 6   However, in the absence of a larger medium-to-...
# 7   One option could be to procure the SLR-66 from...
# 8   Thus, Quwa does not accept responsibility or l...
# 9   In the year to come, under the guidance of Xi ...
# 10  He also expressed sincere appreciation to memb...
# 11  These components could contain malicious code ...
# 12  This executive order is a good first step, but...
# 13  The Air Force will need support from industry ...
# 14  How do we improve the further resilience of th...
# 15  Minting the term in official doctrine will fil...
# 16  The team is making terrific progress. I couldn...
# 17  This includes implementation of Joint All Doma...
# 18  But they will also have a sharper influence on...
#
#                                               last250  \
# 0    and millions of Turkish citizens. Some 250 pe...
# 1   message that Shehbaz Sharif’s efforts to persu...
# 2   death" of NATO, where Turkey is a key member  ...
# 3   also summoned the files of the Ministry of Ove...
# 4    The status of Eritrean troops remains unclear...
# 5   And unlike his predecessors, Mr Li has not acc...
# 6   The JF-17 reportedly has an airframe life of 3...
# 7   The PN added that the â€œoperationalization of...
# 8   Islamabad 29 November, 2019:- The Pakistan Air...
# 9   original aspiration and spared no effort to st...
# 10  global economic recovery and development. He a...
# 11  to exploit for valuable information and intell...
# 12  lesser network problem, the order creates a pl...
# 13  ”The misconception that adversaries’ priority ...
# 14  1st Special Forces Command built an specifical...
# 15   Hersey describes five pillars of information ...
# 16  A single major discovery in early development,...
# 17  Since then, Iron Dome has played an instrument...
# 18  The concept, as readers know, is the capstone ...
#
#                                                onecom  \
# 0   A whopping majority of Turkish people do not t...
# 1   A few days ago, PML-N President and Opposition...
# 2   French President Emmanuel Macron said Thursday...
# 3   Former special assistant to prime minister (SA...
# 4   The rebels have now entered the town of Shire,...
# 5   The critically acclaimed Radio Television Hong...
# 6   On 26 September, the Pakistan Air Force (PAF) ...
# 7   On 05 November 2019, the Pakistan Navy (PN) an...
# 8   The Pakistan Air Force conducted a command lev...
# 9   In the new year, we hope that the US side coul...
# 10  The relationship between China and the United ...
# 11  A group of top U.S. national security agencies...
# 12  Following government cyber breaches, the Biden...
# 13  A top Air Force general wants to dispel the co...
# 14  U.S. Special Operations Command created a task...
# 15  The U.S. Army will soon make “information adva...
# 16  Northrop Grumman uses its Highly Immersive Vir...
# 17   The performance of the Israeli Iron Dome air ...
# 18   In a clear sign that China really is the Bide...
#
#                                                twocom  \
# 0   A whopping majority of Turkish people do not t...
# 1   A few days ago, PML-N President and Opposition...
# 2   French President Emmanuel Macron said Thursday...
# 3   Former special assistant to prime minister (SA...
# 4   The rebels have now entered the town of Shire,...
# 5   The critically acclaimed Radio Television Hong...
# 6   On 26 September, the Pakistan Air Force (PAF) ...
# 7   On 05 November 2019, the Pakistan Navy (PN) an...
# 8   The Pakistan Air Force conducted a command lev...
# 9   In the new year, we hope that the US side coul...
# 10  The relationship between China and the United ...
# 11  A group of top U.S. national security agencies...
# 12  Following government cyber breaches, the Biden...
# 13  A top Air Force general wants to dispel the co...
# 14  U.S. Special Operations Command created a task...
# 15  The U.S. Army will soon make “information adva...
# 16  Northrop Grumman uses its Highly Immersive Vir...
# 17  The performance of the Israeli Iron Dome air d...
# 18  In a clear sign that China really is the Biden...
#
#                                              threecom  \
# 0   A whopping majority of Turkish people do not t...
# 1   A few days ago, PML-N President and Opposition...
# 2   French President Emmanuel Macron said Thursday...
# 3   Former special assistant to prime minister (SA...
# 4   The rebels have now entered the town of Shire,...
# 5   The critically acclaimed Radio Television Hong...
# 6   On 26 September, the Pakistan Air Force (PAF) ...
# 7   On 05 November 2019, the Pakistan Navy (PN) an...
# 8   Thus, Quwa does not accept responsibility or l...
# 9   In the new year, we hope that the US side coul...
# 10  The relationship between China and the United ...
# 11  A group of top U.S. national security agencies...
# 12  Following government cyber breaches, the Biden...
# 13   A top Air Force general wants to dispel the c...
# 14  U.S. Special Operations Command created a task...
# 15  The U.S. Army will soon make “information adva...
# 16  Northrop Grumman uses its Highly Immersive Vir...
# 17  The performance of the Israeli Iron Dome air d...
# 18  In a clear sign that China really is the Biden...
#
#                                                com250               domain
# 0   A whopping majority of Turkish people do not t...             politics
# 1   A few days ago, PML-N President and Opposition...             politics
# 2   French President Emmanuel Macron said Thursday...             politics
# 3   Former special assistant to prime minister (SA...                crime
# 4   The rebels have now entered the town of Shire,...        international
# 5   The critically acclaimed Radio Television Hong...        international
# 6   On 26 September, the Pakistan Air Force (PAF) ...             National
# 7   On 05 November 2019, the Pakistan Navy (PN) an...             National
# 8   Islamabad 29 November, 2019:- The Pakistan Air...             National
# 9   In the new year, we hope that the US side coul...           government
# 10  The relationship between China and the United ...           government
# 11  A group of top U.S. national security agencies...       cyber security
# 12  Following government cyber breaches, the Biden...       cyber security
# 13  A top Air Force general wants to dispel the co...  Information Warfare
# 14  U.S. Special Operations Command created a task...  Information Warfare
# 15  The U.S. Army will soon make “information adva...  Information Warfare
# 16  Northrop Grumman uses its Highly Immersive Vir...               Threat
# 17  The performance of the Israeli Iron Dome air d...               Threat
# 18  In a clear sign that China really is the Biden...               Threat

# %%
df.shape
# Out:
# (19, 14)

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.19.1-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 30.8 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.6.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.0 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 44.4 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 37.9 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.6.0 pyyaml-6.0 tokenizers-0.12.1 transformers-4.19.1

# %%
import numpy as np
import matplotlib.pyplot as plt
from transformers import pipeline
from pylab import rcParams

# %%
from transformers import pipeline
zero_shot_classifier = pipeline("zero-shot-classification",model="facebook/bart-large-mnli")
# Out:
# Downloading:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
hypothesis_template = 'This text is about {} .'

# %% [markdown]
# **Title**

# %%
listt = []
for i in range(len(df.title)):
  sequence = ["{s}".format(s=df.title[i])]
  #candidate_labels = ["Crime", "Politics", "National", "Information Warfare","Threats","Cyber Security","Government","International"]
  candidate_labels = ["Crime", "Politics", "Terrorism", "Finance","Sports","Entertainment","Others"]  
  poping_sequence = zero_shot_classifier(sequence, candidate_labels,hypothesis_template=hypothesis_template, multi_label=False)
  listt.append(poping_sequence)
  #print(poping_sequence)

# %%
listt
# Out:
# [[{'labels': ['Others',
#     'Politics',
#     'Crime',
#     'Finance',
#     'Terrorism',
#     'Sports',
#     'Entertainment'],
#    'scores': [0.35370612144470215,
#     0.31280025839805603,
#     0.09658411890268326,
#     0.06587602198123932,
#     0.06492257118225098,
#     0.059437308460474014,
#     0.04667355865240097],
#    'sequence': 'Majority of Turkish people do not trust NATO: Survey'}],
#  [{'labels': ['Politics',
#     'Others',
#     'Crime',
#     'Finance',
#     'Entertainment',
#     'Sports',
#     'Terrorism'],
#    'scores': [0.5840197801589966,
#     0.20370209217071533,
#     0.05124051868915558,
#     0.04820729047060013,
#     0.03893366456031799,
#     0.03716525435447693,
#     0.03673137351870537],
#    'sequence': 'Fissures become apparent in PML N leadership'}],
#  [{'labels': ['Others',
#     'Politics',
#     'Crime',
#     'Terrorism',
#     'Finance',
#     'Entertainment',
#     'Sports'],
#    'scores': [0.5123754143714905,
#     0.26190316677093506,
#     0.06635663658380508,
#     0.05130986496806145,
#     0.048589710146188736,
#     0.03404700383543968,
#     0.025418203324079514],
#    'sequence': 'Macron wants to meet ErdoÄŸan ahead of NATO summit'}],
#  [{'labels': ['Crime',
#     'Politics',
#     'Others',
#     'Finance',
#     'Terrorism',
#     'Sports',
#     'Entertainment'],
#    'scores': [0.5086750984191895,
#     0.2051641047000885,
#     0.10652235895395279,
#     0.060424551367759705,
#     0.05440515652298927,
#     0.036281660199165344,
#     0.028526999056339264],
#    'sequence': 'Former SAPM Zulfi Bukhari returns back to Pakistan, offered himself for accountability into Rawalpindi Ring Road scam'}],
#  [{'labels': ['Politics',
#     'Others',
#     'Crime',
#     'Terrorism',
#     'Finance',
#     'Entertainment',
#     'Sports'],
#    'scores': [0.3234775960445404,
#     0.31444981694221497,
#     0.18297772109508514,
#     0.06393684446811676,
#     0.050080806016922,
#     0.03393948823213577,
#     0.031137827783823013],
#    'sequence': 'Ethiopia Tigray conflict: Rebels build on capture of capital'}],
#  [{'labels': ['Politics',
#     'Crime',
#     'Others',
#     'Entertainment',
#     'Finance',
#     'Sports',
#     'Terrorism'],
#    'scores': [0.24746684730052948,
#     0.23997871577739716,
#     0.20043903589248657,
#     0.09199721366167068,
#     0.0825025737285614,
#     0.07002825289964676,
#     0.06758735328912735],
#    'sequence': "RTHK: How authorities cracked down on Hong Kong's only public broadcaster"}],
#  [{'labels': ['Terrorism',
#     'Others',
#     'Politics',
#     'Crime',
#     'Finance',
#     'Sports',
#     'Entertainment'],
#    'scores': [0.3172614872455597,
#     0.2600683271884918,
#     0.12597256898880005,
#     0.10402575880289078,
#     0.06780693680047989,
#     0.06267101317644119,
#     0.06219393014907837],
#    'sequence': 'Pakistan Rolls Out First Locally Overhauled JF-17 Fighters'}],
#  [{'labels': ['Others',
#     'Crime',
#     'Politics',
#     'Terrorism',
#     'Sports',
#     'Finance',
#     'Entertainment'],
#    'scores': [0.401448518037796,
#     0.17114707827568054,
#     0.13706021010875702,
#     0.11313308030366898,
#     0.06632062792778015,
#     0.06561124324798584,
#     0.045279331505298615],
#    'sequence': 'Pakistan Navy Tests Land-Based Anti-Ship Missile (Zarb)'}],
#  [{'labels': ['Others',
#     'Sports',
#     'Politics',
#     'Entertainment',
#     'Terrorism',
#     'Crime',
#     'Finance'],
#    'scores': [0.38549312949180603,
#     0.16042789816856384,
#     0.13389277458190918,
#     0.11634752154350281,
#     0.0870383009314537,
#     0.06975935399532318,
#     0.04704105481505394],
#    'sequence': 'Press Release: Pakistan Air Force Conducts Hawk-Eye Exercise (Video)'}],
#  [{'labels': ['Others',
#     'Politics',
#     'Crime',
#     'Sports',
#     'Entertainment',
#     'Finance',
#     'Terrorism'],
#    'scores': [0.4533538818359375,
#     0.22778956592082977,
#     0.08497802168130875,
#     0.07290100306272507,
#     0.06819001585245132,
#     0.0561918243765831,
#     0.03659568354487419],
#    'sequence': 'Regular Press Conference of the Ministry of National Defense on December 31'}],
#  [{'labels': ['Politics',
#     'Others',
#     'Crime',
#     'Entertainment',
#     'Sports',
#     'Finance',
#     'Terrorism'],
#    'scores': [0.36493074893951416,
#     0.2623387575149536,
#     0.09099757671356201,
#     0.08048509061336517,
#     0.07440418750047684,
#     0.07070647180080414,
#     0.05613722279667854],
#    'sequence': "Wang Yi: China-U.S. relationship is 'at an important juncture'"}],
#  [{'labels': ['Others',
#     'Crime',
#     'Politics',
#     'Finance',
#     'Terrorism',
#     'Sports',
#     'Entertainment'],
#    'scores': [0.5914570689201355,
#     0.09850297123193741,
#     0.08636462688446045,
#     0.06312791258096695,
#     0.05862610787153244,
#     0.05562743544578552,
#     0.046293798834085464],
#    'sequence': 'National security agencies warn of 5G network vulnerabilities, adversary influence'}],
#  [{'labels': ['Politics',
#     'Others',
#     'Crime',
#     'Finance',
#     'Terrorism',
#     'Sports',
#     'Entertainment'],
#    'scores': [0.36419567465782166,
#     0.3104321360588074,
#     0.13497988879680634,
#     0.06584557890892029,
#     0.06421373784542084,
#     0.033978886902332306,
#     0.02635415829718113],
#    'sequence': 'Biden orders wide cybersecurity changes for government, contractors'}],
#  [{'labels': ['Others',
#     'Politics',
#     'Crime',
#     'Sports',
#     'Terrorism',
#     'Finance',
#     'Entertainment'],
#    'scores': [0.47180265188217163,
#     0.1797175109386444,
#     0.13286949694156647,
#     0.05904105678200722,
#     0.05769806727766991,
#     0.055726341903209686,
#     0.043144918978214264],
#    'sequence': 'Air Force general busts myth that enemies always try to stop rivals’ communications'}],
#  [{'labels': ['Others',
#     'Crime',
#     'Politics',
#     'Terrorism',
#     'Finance',
#     'Sports',
#     'Entertainment'],
#    'scores': [0.513837993144989,
#     0.19098544120788574,
#     0.1058604046702385,
#     0.06583108752965927,
#     0.05226380378007889,
#     0.04168620705604553,
#     0.029535062611103058],
#    'sequence': 'Special Operations team in Pacific will confront Chinese information campaigns'}],
#  [{'labels': ['Others',
#     'Politics',
#     'Crime',
#     'Entertainment',
#     'Finance',
#     'Terrorism',
#     'Sports'],
#    'scores': [0.4533275365829468,
#     0.1293489933013916,
#     0.11201868206262589,
#     0.08910219371318817,
#     0.07392323017120361,
#     0.07138297706842422,
#     0.07089640200138092],
#    'sequence': 'US Army emphasizes ‘information advantage’'}],
#  [{'labels': ['Crime',
#     'Others',
#     'Terrorism',
#     'Sports',
#     'Finance',
#     'Politics',
#     'Entertainment'],
#    'scores': [0.2759098708629608,
#     0.2705421447753906,
#     0.22517339885234833,
#     0.08321889489889145,
#     0.06522848457098007,
#     0.05449724197387695,
#     0.02542990632355213],
#    'sequence': 'Early Risk Reduction For The Bomber Of The Future'}],
#  [{'labels': ['Others',
#     'Politics',
#     'Terrorism',
#     'Crime',
#     'Finance',
#     'Sports',
#     'Entertainment'],
#    'scores': [0.3545551002025604,
#     0.22417527437210083,
#     0.11969570815563202,
#     0.10526963323354721,
#     0.09748565405607224,
#     0.05353684723377228,
#     0.045281894505023956],
#    'sequence': 'US Talks With Israel About Buying More Iron Dome Systems'}],
#  [{'labels': ['Others',
#     'Politics',
#     'Crime',
#     'Terrorism',
#     'Sports',
#     'Entertainment',
#     'Finance'],
#    'scores': [0.41981571912765503,
#     0.2326662391424179,
#     0.12754391133785248,
#     0.07368191331624985,
#     0.05615008622407913,
#     0.04622042551636696,
#     0.04392167553305626],
#    'sequence': 'SecDef Austin Takes Personal Charge of DoD China Policy With Classified Directive'}]]

# %%
l_a=[]
l_b=[]
l_c=[]
l_d=[]
l_e=[]
l_f=[]
l_g=[]
l_h=[]
for j in range(len(listt)): 
    a=listt[j][0]['labels'][0]
    b=listt[j][0]['scores'][0]
    c=listt[j][0]['labels'][1]
    d=listt[j][0]['scores'][1]
    e=listt[j][0]['labels'][2]
    f=listt[j][0]['scores'][2]
    g=listt[j][0]['labels'][3]
    h=listt[j][0]['scores'][3]
    l_a.append(a)
    l_b.append(b)
    l_c.append(c)
    l_d.append(d)
    l_e.append(e)
    l_f.append(f)
    l_g.append(g)
    l_h.append(h)

# %%
data_title = {'token':df.title,'label1':l_a,'score1':l_b,'label2':l_c,'score2':l_d,'label3':l_e,'score3':l_f,'label14':l_g,'score4':l_h}
df_title = pd.DataFrame(data_title)

# %%
df_title
# Out:
#                                                 token     label1    score1  \
# 0   Majority of Turkish people do not trust NATO: ...     Others  0.353706
# 1        Fissures become apparent in PML N leadership   Politics  0.584020
# 2   Macron wants to meet ErdoÄŸan ahead of NATO su...     Others  0.512375
# 3   Former SAPM Zulfi Bukhari returns back to Paki...      Crime  0.508675
# 4   Ethiopia Tigray conflict: Rebels build on capt...   Politics  0.323478
# 5   RTHK: How authorities cracked down on Hong Kon...   Politics  0.247467
# 6   Pakistan Rolls Out First Locally Overhauled JF...  Terrorism  0.317261
# 7   Pakistan Navy Tests Land-Based Anti-Ship Missi...     Others  0.401449
# 8   Press Release: Pakistan Air Force Conducts Haw...     Others  0.385493
# 9   Regular Press Conference of the Ministry of Na...     Others  0.453354
# 10  Wang Yi: China-U.S. relationship is 'at an imp...   Politics  0.364931
# 11  National security agencies warn of 5G network ...     Others  0.591457
# 12  Biden orders wide cybersecurity changes for go...   Politics  0.364196
# 13  Air Force general busts myth that enemies alwa...     Others  0.471803
# 14  Special Operations team in Pacific will confro...     Others  0.513838
# 15         US Army emphasizes ‘information advantage’     Others  0.453328
# 16  Early Risk Reduction For The Bomber Of The Future      Crime  0.275910
# 17  US Talks With Israel About Buying More Iron Do...     Others  0.354555
# 18  SecDef Austin Takes Personal Charge of DoD Chi...     Others  0.419816
#
#       label2    score2     label3    score3        label14    score4
# 0   Politics  0.312800      Crime  0.096584        Finance  0.065876
# 1     Others  0.203702      Crime  0.051241        Finance  0.048207
# 2   Politics  0.261903      Crime  0.066357      Terrorism  0.051310
# 3   Politics  0.205164     Others  0.106522        Finance  0.060425
# 4     Others  0.314450      Crime  0.182978      Terrorism  0.063937
# 5      Crime  0.239979     Others  0.200439  Entertainment  0.091997
# 6     Others  0.260068   Politics  0.125973          Crime  0.104026
# 7      Crime  0.171147   Politics  0.137060      Terrorism  0.113133
# 8     Sports  0.160428   Politics  0.133893  Entertainment  0.116348
# 9   Politics  0.227790      Crime  0.084978         Sports  0.072901
# 10    Others  0.262339      Crime  0.090998  Entertainment  0.080485
# 11     Crime  0.098503   Politics  0.086365        Finance  0.063128
# 12    Others  0.310432      Crime  0.134980        Finance  0.065846
# 13  Politics  0.179718      Crime  0.132869         Sports  0.059041
# 14     Crime  0.190985   Politics  0.105860      Terrorism  0.065831
# 15  Politics  0.129349      Crime  0.112019  Entertainment  0.089102
# 16    Others  0.270542  Terrorism  0.225173         Sports  0.083219
# 17  Politics  0.224175  Terrorism  0.119696          Crime  0.105270
# 18  Politics  0.232666      Crime  0.127544      Terrorism  0.073682

# %%
df_title.label1.value_counts()
# Out:
# Others       11
# Politics      5
# Crime         2
# Terrorism     1
# Name: label1, dtype: int64

# %%
# bbc data , apna data , apne labels , multi label true and false 
# sklean f1 score
# classfication_reprot

# %%
l_a
# Out:
# ['Others',
#  'Politics',
#  'Others',
#  'Crime',
#  'Politics',
#  'Politics',
#  'Terrorism',
#  'Others',
#  'Others',
#  'Others',
#  'Politics',
#  'Others',
#  'Politics',
#  'Others',
#  'Others',
#  'Others',
#  'Crime',
#  'Others',
#  'Others']

# %%
traverse = {'title':l_a}
dftra = pd.DataFrame(traverse)

# %%
dftra
# Out:
#         title
# 0      Others
# 1    Politics
# 2      Others
# 3       Crime
# 4    Politics
# 5    Politics
# 6   Terrorism
# 7      Others
# 8      Others
# 9      Others
# 10   Politics
# 11     Others
# 12   Politics
# 13     Others
# 14     Others
# 15     Others
# 16      Crime
# 17     Others
# 18     Others

# %%
df['dom'] = l_a

# %%
df
# Out:
#                                                 title  \
# 0   Majority of Turkish people do not trust NATO: ...
# 1        Fissures become apparent in PML N leadership
# 2   Macron wants to meet ErdoÄŸan ahead of NATO su...
# 3   Former SAPM Zulfi Bukhari returns back to Paki...
# 4   Ethiopia Tigray conflict: Rebels build on capt...
# 5   RTHK: How authorities cracked down on Hong Kon...
# 6   Pakistan Rolls Out First Locally Overhauled JF...
# 7   Pakistan Navy Tests Land-Based Anti-Ship Missi...
# 8   Press Release: Pakistan Air Force Conducts Haw...
# 9   Regular Press Conference of the Ministry of Na...
# 10  Wang Yi: China-U.S. relationship is 'at an imp...
# 11  National security agencies warn of 5G network ...
# 12  Biden orders wide cybersecurity changes for go...
# 13  Air Force general busts myth that enemies alwa...
# 14  Special Operations team in Pacific will confro...
# 15         US Army emphasizes ‘information advantage’
# 16  Early Risk Reduction For The Bomber Of The Future
# 17  US Talks With Israel About Buying More Iron Do...
# 18  SecDef Austin Takes Personal Charge of DoD Chi...
#
#                                              firstone  \
# 0   A whopping majority of Turkish people do not t...
# 1   A few days ago, PML-N President and Opposition...
# 2   French President Emmanuel Macron said Thursday...
# 3   Former special assistant to prime minister (SA...
# 4   The rebels have now entered the town of Shire,...
# 5   The critically acclaimed Radio Television Hong...
# 6   On 26 September, the Pakistan Air Force (PAF) ...
# 7   On 05 November 2019, the Pakistan Navy (PN) an...
# 8   The Pakistan Air Force conducted a command lev...
# 9   In the new year, we hope that the US side coul...
# 10  The relationship between China and the United ...
# 11  A group of top U.S. national security agencies...
# 12  Following government cyber breaches, the Biden...
# 13  A top Air Force general wants to dispel the co...
# 14  U.S. Special Operations Command created a task...
# 15  The U.S. Army will soon make “information adva...
# 16  Northrop Grumman uses its Highly Immersive Vir...
# 17   The performance of the Israeli Iron Dome air ...
# 18   In a clear sign that China really is the Bide...
#
#                                              firsttwo  \
# 0   A whopping majority of Turkish people do not t...
# 1   A few days ago, PML-N President and Opposition...
# 2   French President Emmanuel Macron said Thursday...
# 3   Former special assistant to prime minister (SA...
# 4   The rebels have now entered the town of Shire,...
# 5   The critically acclaimed Radio Television Hong...
# 6   On 26 September, the Pakistan Air Force (PAF) ...
# 7   On 05 November 2019, the Pakistan Navy (PN) an...
# 8   The Pakistan Air Force conducted a command lev...
# 9   In the new year, we hope that the US side coul...
# 10  The relationship between China and the United ...
# 11  A group of top U.S. national security agencies...
# 12  Following government cyber breaches, the Biden...
# 13  A top Air Force general wants to dispel the co...
# 14  U.S. Special Operations Command created a task...
# 15  The U.S. Army will soon make “information adva...
# 16  Northrop Grumman uses its Highly Immersive Vir...
# 17  The performance of the Israeli Iron Dome air d...
# 18  In a clear sign that China really is the Biden...
#
#                                            firstthree  \
# 0   A whopping majority of Turkish people do not t...
# 1   A few days ago, PML-N President and Opposition...
# 2   French President Emmanuel Macron said Thursday...
# 3   Former special assistant to prime minister (SA...
# 4   The rebels have now entered the town of Shire,...
# 5   The critically acclaimed Radio Television Hong...
# 6   On 26 September, the Pakistan Air Force (PAF) ...
# 7   On 05 November 2019, the Pakistan Navy (PN) an...
# 8   The Pakistan Air Force conducted a command lev...
# 9   In the new year, we hope that the US side coul...
# 10  The relationship between China and the United ...
# 11  A group of top U.S. national security agencies...
# 12  Following government cyber breaches, the Biden...
# 13   A top Air Force general wants to dispel the c...
# 14  U.S. Special Operations Command created a task...
# 15  The U.S. Army will soon make “information adva...
# 16  Northrop Grumman uses its Highly Immersive Vir...
# 17  The performance of the Israeli Iron Dome air d...
# 18  In a clear sign that China really is the Biden...
#
#                                              first250  \
# 0   A whopping majority of Turkish people do not t...
# 1   A few days ago, PML-N President and Opposition...
# 2   French President Emmanuel Macron said Thursday...
# 3   Former special assistant to prime minister (SA...
# 4   The rebels have now entered the town of Shire,...
# 5   The critically acclaimed Radio Television Hong...
# 6   On 26 September, the Pakistan Air Force (PAF) ...
# 7   On 05 November 2019, the Pakistan Navy (PN) an...
# 8   Islamabad 29 November, 2019:- The Pakistan Air...
# 9   In the new year, we hope that the US side coul...
# 10  The relationship between China and the United ...
# 11  A group of top U.S. national security agencies...
# 12  Following government cyber breaches, the Biden...
# 13  A top Air Force general wants to dispel the co...
# 14  U.S. Special Operations Command created a task...
# 15  The U.S. Army will soon make “information adva...
# 16  Northrop Grumman uses its Highly Immersive Vir...
# 17  The performance of the Israeli Iron Dome air d...
# 18  In a clear sign that China really is the Biden...
#
#                                               lastone  \
# 0    The alliance is based on the core principle o...
# 1    But he had to face embarrassment at the hands...
# 2    We must ensure that no misunderstanding comes...
# 3   is ensured that the new alignment is free from...
# 4    The UN has said there was a situation of fami...
# 5   "2019 was a turning point and [the crackdown] ...
# 6   Tomislav Mesaric. â€œPride of Pakistanâ€. Air...
# 7    According to the Pakistan Ministry of Defence...
# 8    If your company would like to request Quwa to...
# 9   Despite challenges and difficulties, they will...
# 10  The Chinese foreign minister urged to work tog...
# 11  These vulnerabilities could then later be expl...
# 12  Mark Warner, D-Virginia, chairman of the Intel...
# 13  “We’ll need capabilities to streamline the spe...
# 14   This is something that U.S. Cyber Command and...
# 15  Given how quickly the information domain evolv...
# 16  we have innovative applications of digital too...
# 17  The largest of the four categories is called “...
# 18  With today’s directive, the task force is no m...
#
#                                               lasttwo  \
# 0    Turkey is important for NATO, but NATO is als...
# 1    As a matter of principle, Shehbaz Sharif’s in...
# 2    And they will remain so. We must ensure that ...
# 3   Rawalpindi Commissioner Syed Gulzar Hussain Sh...
# 4   State department spokesperson Ned Price said t...
# 5   Analysts say the changes to RTHK are yet anoth...
# 6   The which will be the JF-17â€™s most extensive...
# 7   Having acquired long-range subsonic ASCMs, the...
# 8    Quwa does not grant rights to reproduce or us...
# 9   They will adopt a holistic approach to nationa...
# 10  Oxen are known for their diligence and strengt...
# 11  Flaws or malware inserted early in the develop...
# 12  Congress is going to have to step up and do mo...
# 13  Culture also must change to accept automation,...
# 14  “This is not going to be episodic. This is som...
# 15  The Army in 2017 released the to integrate cyb...
# 16  What we have on the production line now are so...
# 17  In this brief video interview, Northrop Grumma...
# 18  “The initiatives I am putting forward today ar...
#
#                                             lastthree  \
# 0    Despite this fluctuating relationship, NATO c...
# 1   At this juncture the question is not whether t...
# 2    During the visit, parth said Turkey and Franc...
# 3    The Punjab government said that former commis...
# 4    On Tuesday, senior US state department offici...
# 5     "Many of them think that RTHK should not bit...
# 6   However, in the absence of a larger medium-to-...
# 7   One option could be to procure the SLR-66 from...
# 8   Thus, Quwa does not accept responsibility or l...
# 9   In the year to come, under the guidance of Xi ...
# 10  He also expressed sincere appreciation to memb...
# 11  These components could contain malicious code ...
# 12  This executive order is a good first step, but...
# 13  The Air Force will need support from industry ...
# 14  How do we improve the further resilience of th...
# 15  Minting the term in official doctrine will fil...
# 16  The team is making terrific progress. I couldn...
# 17  This includes implementation of Joint All Doma...
# 18  But they will also have a sharper influence on...
#
#                                               last250  \
# 0    and millions of Turkish citizens. Some 250 pe...
# 1   message that Shehbaz Sharif’s efforts to persu...
# 2   death" of NATO, where Turkey is a key member  ...
# 3   also summoned the files of the Ministry of Ove...
# 4    The status of Eritrean troops remains unclear...
# 5   And unlike his predecessors, Mr Li has not acc...
# 6   The JF-17 reportedly has an airframe life of 3...
# 7   The PN added that the â€œoperationalization of...
# 8   Islamabad 29 November, 2019:- The Pakistan Air...
# 9   original aspiration and spared no effort to st...
# 10  global economic recovery and development. He a...
# 11  to exploit for valuable information and intell...
# 12  lesser network problem, the order creates a pl...
# 13  ”The misconception that adversaries’ priority ...
# 14  1st Special Forces Command built an specifical...
# 15   Hersey describes five pillars of information ...
# 16  A single major discovery in early development,...
# 17  Since then, Iron Dome has played an instrument...
# 18  The concept, as readers know, is the capstone ...
#
#                                                onecom  \
# 0   A whopping majority of Turkish people do not t...
# 1   A few days ago, PML-N President and Opposition...
# 2   French President Emmanuel Macron said Thursday...
# 3   Former special assistant to prime minister (SA...
# 4   The rebels have now entered the town of Shire,...
# 5   The critically acclaimed Radio Television Hong...
# 6   On 26 September, the Pakistan Air Force (PAF) ...
# 7   On 05 November 2019, the Pakistan Navy (PN) an...
# 8   The Pakistan Air Force conducted a command lev...
# 9   In the new year, we hope that the US side coul...
# 10  The relationship between China and the United ...
# 11  A group of top U.S. national security agencies...
# 12  Following government cyber breaches, the Biden...
# 13  A top Air Force general wants to dispel the co...
# 14  U.S. Special Operations Command created a task...
# 15  The U.S. Army will soon make “information adva...
# 16  Northrop Grumman uses its Highly Immersive Vir...
# 17   The performance of the Israeli Iron Dome air ...
# 18   In a clear sign that China really is the Bide...
#
#                                                twocom  \
# 0   A whopping majority of Turkish people do not t...
# 1   A few days ago, PML-N President and Opposition...
# 2   French President Emmanuel Macron said Thursday...
# 3   Former special assistant to prime minister (SA...
# 4   The rebels have now entered the town of Shire,...
# 5   The critically acclaimed Radio Television Hong...
# 6   On 26 September, the Pakistan Air Force (PAF) ...
# 7   On 05 November 2019, the Pakistan Navy (PN) an...
# 8   The Pakistan Air Force conducted a command lev...
# 9   In the new year, we hope that the US side coul...
# 10  The relationship between China and the United ...
# 11  A group of top U.S. national security agencies...
# 12  Following government cyber breaches, the Biden...
# 13  A top Air Force general wants to dispel the co...
# 14  U.S. Special Operations Command created a task...
# 15  The U.S. Army will soon make “information adva...
# 16  Northrop Grumman uses its Highly Immersive Vir...
# 17  The performance of the Israeli Iron Dome air d...
# 18  In a clear sign that China really is the Biden...
#
#                                              threecom  \
# 0   A whopping majority of Turkish people do not t...
# 1   A few days ago, PML-N President and Opposition...
# 2   French President Emmanuel Macron said Thursday...
# 3   Former special assistant to prime minister (SA...
# 4   The rebels have now entered the town of Shire,...
# 5   The critically acclaimed Radio Television Hong...
# 6   On 26 September, the Pakistan Air Force (PAF) ...
# 7   On 05 November 2019, the Pakistan Navy (PN) an...
# 8   Thus, Quwa does not accept responsibility or l...
# 9   In the new year, we hope that the US side coul...
# 10  The relationship between China and the United ...
# 11  A group of top U.S. national security agencies...
# 12  Following government cyber breaches, the Biden...
# 13   A top Air Force general wants to dispel the c...
# 14  U.S. Special Operations Command created a task...
# 15  The U.S. Army will soon make “information adva...
# 16  Northrop Grumman uses its Highly Immersive Vir...
# 17  The performance of the Israeli Iron Dome air d...
# 18  In a clear sign that China really is the Biden...
#
#                                                com250               domain  \
# 0   A whopping majority of Turkish people do not t...             politics
# 1   A few days ago, PML-N President and Opposition...             politics
# 2   French President Emmanuel Macron said Thursday...             politics
# 3   Former special assistant to prime minister (SA...                crime
# 4   The rebels have now entered the town of Shire,...        international
# 5   The critically acclaimed Radio Television Hong...        international
# 6   On 26 September, the Pakistan Air Force (PAF) ...             National
# 7   On 05 November 2019, the Pakistan Navy (PN) an...             National
# 8   Islamabad 29 November, 2019:- The Pakistan Air...             National
# 9   In the new year, we hope that the US side coul...           government
# 10  The relationship between China and the United ...           government
# 11  A group of top U.S. national security agencies...       cyber security
# 12  Following government cyber breaches, the Biden...       cyber security
# 13  A top Air Force general wants to dispel the co...  Information Warfare
# 14  U.S. Special Operations Command created a task...  Information Warfare
# 15  The U.S. Army will soon make “information adva...  Information Warfare
# 16  Northrop Grumman uses its Highly Immersive Vir...               Threat
# 17  The performance of the Israeli Iron Dome air d...               Threat
# 18  In a clear sign that China really is the Biden...               Threat
#
#           dom
# 0      Others
# 1    Politics
# 2      Others
# 3       Crime
# 4    Politics
# 5    Politics
# 6   Terrorism
# 7      Others
# 8      Others
# 9      Others
# 10   Politics
# 11     Others
# 12   Politics
# 13     Others
# 14     Others
# 15     Others
# 16      Crime
# 17     Others
# 18     Others

# %% [markdown]
# **first sentence**

# %%
firstone_list = []
for i in range(len(df.firstone)):
  sequence = ["{s}".format(s=df.firstone[i])]
  #candidate_labels = ["Crime", "Politics", "National", "Information Warfare","Threats","Cyber Security","Government","International"]
  candidate_labels = ["Crime", "Politics", "Terrorism", "Finance","Sports","Entertainment","Others"] 
  poping_sequence = zero_shot_classifier(sequence, candidate_labels,hypothesis_template=hypothesis_template, multi_label=False)
  firstone_list.append(poping_sequence)
  #print(poping_sequence)

# %%
l_a=[]
l_b=[]
l_c=[]
l_d=[]
l_e=[]
l_f=[]
l_g=[]
l_h=[]
for j in range(len(df.firstone)): 
    a=firstone_list[j][0]['labels'][0]
    b=firstone_list[j][0]['scores'][0]
    c=firstone_list[j][0]['labels'][1]
    d=firstone_list[j][0]['scores'][1]
    e=firstone_list[j][0]['labels'][2]
    f=firstone_list[j][0]['scores'][2]
    g=firstone_list[j][0]['labels'][3]
    h=firstone_list[j][0]['scores'][3]
    l_a.append(a)
    l_b.append(b)
    l_c.append(c)
    l_d.append(d)
    l_e.append(e)
    l_f.append(f)
    l_g.append(g)
    l_h.append(h)

# %%
fo_title = {'first one ':df.firstone,'domain of title ':df.dom,'label1':l_a,'score1':l_b,'label2':l_c,'score2':l_d,'label3':l_e,'score3':l_f,'label14':l_g,'score4':l_h}
dfo_title = pd.DataFrame(fo_title)

# %%
dfo_title
# Out:
#                                            first one  domain of title   \
# 0   A whopping majority of Turkish people do not t...           Others
# 1   A few days ago, PML-N President and Opposition...         Politics
# 2   French President Emmanuel Macron said Thursday...           Others
# 3   Former special assistant to prime minister (SA...            Crime
# 4   The rebels have now entered the town of Shire,...         Politics
# 5   The critically acclaimed Radio Television Hong...         Politics
# 6   On 26 September, the Pakistan Air Force (PAF) ...        Terrorism
# 7   On 05 November 2019, the Pakistan Navy (PN) an...           Others
# 8   The Pakistan Air Force conducted a command lev...           Others
# 9   In the new year, we hope that the US side coul...           Others
# 10  The relationship between China and the United ...         Politics
# 11  A group of top U.S. national security agencies...           Others
# 12  Following government cyber breaches, the Biden...         Politics
# 13  A top Air Force general wants to dispel the co...           Others
# 14  U.S. Special Operations Command created a task...           Others
# 15  The U.S. Army will soon make “information adva...           Others
# 16  Northrop Grumman uses its Highly Immersive Vir...            Crime
# 17   The performance of the Israeli Iron Dome air ...           Others
# 18   In a clear sign that China really is the Bide...           Others
#
#       label1    score1         label2    score2     label3    score3  \
# 0   Politics  0.361376         Others  0.281881      Crime  0.118854
# 1   Politics  0.620928         Others  0.190336      Crime  0.053732
# 2   Politics  0.354282         Others  0.331979      Crime  0.089891
# 3      Crime  0.329676       Politics  0.309136     Others  0.173386
# 4     Others  0.291579          Crime  0.186593  Terrorism  0.176787
# 5     Others  0.386325  Entertainment  0.143180   Politics  0.141201
# 6     Others  0.307868       Politics  0.168737      Crime  0.158299
# 7     Others  0.326678          Crime  0.176746   Politics  0.152324
# 8     Others  0.330163          Crime  0.167204   Politics  0.145736
# 9   Politics  0.320076         Others  0.268004      Crime  0.143649
# 10  Politics  0.382293         Others  0.187197      Crime  0.132610
# 11    Others  0.397504          Crime  0.160776   Politics  0.137376
# 12    Others  0.324768          Crime  0.206056   Politics  0.160308
# 13    Others  0.449092          Crime  0.147968   Politics  0.136605
# 14    Others  0.348511          Crime  0.210333   Politics  0.150758
# 15    Others  0.270497       Politics  0.230145      Crime  0.176011
# 16    Others  0.279527  Entertainment  0.259550      Crime  0.137174
# 17    Others  0.323947       Politics  0.169856      Crime  0.166434
# 18  Politics  0.349739         Others  0.161196      Crime  0.157771
#
#       label14    score4
# 0   Terrorism  0.100595
# 1   Terrorism  0.042515
# 2     Finance  0.059107
# 3   Terrorism  0.065748
# 4    Politics  0.157640
# 5       Crime  0.099783
# 6   Terrorism  0.126945
# 7   Terrorism  0.124897
# 8   Terrorism  0.142356
# 9   Terrorism  0.082779
# 10  Terrorism  0.079865
# 11     Sports  0.086991
# 12    Finance  0.085760
# 13  Terrorism  0.087080
# 14  Terrorism  0.092155
# 15     Sports  0.096813
# 16   Politics  0.107150
# 17  Terrorism  0.111510
# 18  Terrorism  0.101817

# %%
dftra['firstone'] = l_a

# %%
dftra
# Out:
#         title  firstone
# 0      Others  Politics
# 1    Politics  Politics
# 2      Others  Politics
# 3       Crime     Crime
# 4    Politics    Others
# 5    Politics    Others
# 6   Terrorism    Others
# 7      Others    Others
# 8      Others    Others
# 9      Others  Politics
# 10   Politics  Politics
# 11     Others    Others
# 12   Politics    Others
# 13     Others    Others
# 14     Others    Others
# 15     Others    Others
# 16      Crime    Others
# 17     Others    Others
# 18     Others  Politics

# %%
dfo_title.label1.value_counts()
# Out:
# Others      12
# Politics     6
# Crime        1
# Name: label1, dtype: int64

# %% [markdown]
# **first two sentence**

# %%
firsttwo_list = []
for i in range(len(df.firsttwo)):
  sequence = ["{s}".format(s=df.firsttwo[i])]
  #candidate_labels = ["Crime", "Politics", "National", "Information Warfare","Threats","Cyber Security","Government","International"]  
  candidate_labels = ["Crime", "Politics", "Terrorism", "Finance","Sports","Entertainment","Others"] 
  poping_sequence = zero_shot_classifier(sequence, candidate_labels,hypothesis_template=hypothesis_template, multi_label=False)
  firsttwo_list.append(poping_sequence)
  #print(poping_sequence)

# %%
l_a=[]
l_b=[]
l_c=[]
l_d=[]
l_e=[]
l_f=[]
l_g=[]
l_h=[]
for j in range(len(df.firsttwo)): 
    a=firsttwo_list[j][0]['labels'][0]
    b=firsttwo_list[j][0]['scores'][0]
    c=firsttwo_list[j][0]['labels'][1]
    d=firsttwo_list[j][0]['scores'][1]
    e=firsttwo_list[j][0]['labels'][2]
    f=firsttwo_list[j][0]['scores'][2]
    g=firsttwo_list[j][0]['labels'][3]
    h=firsttwo_list[j][0]['scores'][3]
    l_a.append(a)
    l_b.append(b)
    l_c.append(c)
    l_d.append(d)
    l_e.append(e)
    l_f.append(f)
    l_g.append(g)
    l_h.append(h)

# %%
fot_title = {'first two sentence ':df.firsttwo,'title of domain':df.dom,'label1':l_a,'score1':l_b,'label2':l_c,'score2':l_d,'label3':l_e,'score3':l_f,'label14':l_g,'score4':l_h}
dfot_title = pd.DataFrame(fot_title)

# %%
dfot_title
# Out:
#                                   first two sentence  title of domain  \
# 0   A whopping majority of Turkish people do not t...          Others
# 1   A few days ago, PML-N President and Opposition...        Politics
# 2   French President Emmanuel Macron said Thursday...          Others
# 3   Former special assistant to prime minister (SA...           Crime
# 4   The rebels have now entered the town of Shire,...        Politics
# 5   The critically acclaimed Radio Television Hong...        Politics
# 6   On 26 September, the Pakistan Air Force (PAF) ...       Terrorism
# 7   On 05 November 2019, the Pakistan Navy (PN) an...          Others
# 8   The Pakistan Air Force conducted a command lev...          Others
# 9   In the new year, we hope that the US side coul...          Others
# 10  The relationship between China and the United ...        Politics
# 11  A group of top U.S. national security agencies...          Others
# 12  Following government cyber breaches, the Biden...        Politics
# 13  A top Air Force general wants to dispel the co...          Others
# 14  U.S. Special Operations Command created a task...          Others
# 15  The U.S. Army will soon make “information adva...          Others
# 16  Northrop Grumman uses its Highly Immersive Vir...           Crime
# 17  The performance of the Israeli Iron Dome air d...          Others
# 18  In a clear sign that China really is the Biden...          Others
#
#       label1    score1         label2    score2    label3    score3  \
# 0   Politics  0.336309         Others  0.225553     Crime  0.127120
# 1   Politics  0.551590         Others  0.187007     Crime  0.073311
# 2   Politics  0.368398         Others  0.351123     Crime  0.078583
# 3     Others  0.296793       Politics  0.282634     Crime  0.209347
# 4     Others  0.387623       Politics  0.192562     Crime  0.134680
# 5     Others  0.334868       Politics  0.180485     Crime  0.116195
# 6     Others  0.240890          Crime  0.179561  Politics  0.155733
# 7     Others  0.340239       Politics  0.151530     Crime  0.148551
# 8     Others  0.361387          Crime  0.159678  Politics  0.143965
# 9   Politics  0.281577         Others  0.271126     Crime  0.131504
# 10  Politics  0.368171         Others  0.200800     Crime  0.131379
# 11    Others  0.379038          Crime  0.166415  Politics  0.124121
# 12     Crime  0.261691         Others  0.237164  Politics  0.181308
# 13    Others  0.429304          Crime  0.130461  Politics  0.122741
# 14    Others  0.410543       Politics  0.159130     Crime  0.143892
# 15    Others  0.330190          Crime  0.182859  Politics  0.165115
# 16    Others  0.338822  Entertainment  0.174216     Crime  0.156396
# 17    Others  0.291710       Politics  0.211577     Crime  0.161412
# 18    Others  0.264916       Politics  0.248670     Crime  0.150494
#
#           label14    score4
# 0       Terrorism  0.112381
# 1       Terrorism  0.056784
# 2   Entertainment  0.063744
# 3       Terrorism  0.058401
# 4       Terrorism  0.125382
# 5   Entertainment  0.111556
# 6   Entertainment  0.124675
# 7          Sports  0.109899
# 8       Terrorism  0.122492
# 9       Terrorism  0.088460
# 10  Entertainment  0.090350
# 11  Entertainment  0.108333
# 12      Terrorism  0.086295
# 13  Entertainment  0.095528
# 14      Terrorism  0.090688
# 15      Terrorism  0.098794
# 16         Sports  0.106240
# 17      Terrorism  0.127428
# 18      Terrorism  0.088284

# %%
dftra['firsttwo'] = l_a

# %%
dftra
# Out:
#         title  firstone  firsttwo
# 0      Others  Politics  Politics
# 1    Politics  Politics  Politics
# 2      Others  Politics  Politics
# 3       Crime     Crime    Others
# 4    Politics    Others    Others
# 5    Politics    Others    Others
# 6   Terrorism    Others    Others
# 7      Others    Others    Others
# 8      Others    Others    Others
# 9      Others  Politics  Politics
# 10   Politics  Politics  Politics
# 11     Others    Others    Others
# 12   Politics    Others     Crime
# 13     Others    Others    Others
# 14     Others    Others    Others
# 15     Others    Others    Others
# 16      Crime    Others    Others
# 17     Others    Others    Others
# 18     Others  Politics    Others

# %%
dfot_title.label1.value_counts()
# Out:
# Others      13
# Politics     5
# Crime        1
# Name: label1, dtype: int64

# %% [markdown]
# **first three sentence**

# %%
firstthree_list = []
for i in range(len(df.firstthree)):
  sequence = ["{s}".format(s=df.firstthree[i])]
  #candidate_labels = ["Crime", "Politics", "National", "Information Warfare","Threats","Cyber Security","Government","International"]  
  candidate_labels = ["Crime", "Politics", "Terrorism", "Finance","Sports","Entertainment","Others"] 
  poping_sequence = zero_shot_classifier(sequence, candidate_labels,hypothesis_template=hypothesis_template, multi_label=False)
  firstthree_list.append(poping_sequence)
  #print(poping_sequence)

# %%
l_a=[]
l_b=[]
l_c=[]
l_d=[]
l_e=[]
l_f=[]
l_g=[]
l_h=[]
for j in range(len(df.firstthree)): 
    a=firstthree_list[j][0]['labels'][0]
    b=firstthree_list[j][0]['scores'][0]
    c=firstthree_list[j][0]['labels'][1]
    d=firstthree_list[j][0]['scores'][1]
    e=firstthree_list[j][0]['labels'][2]
    f=firstthree_list[j][0]['scores'][2]
    g=firstthree_list[j][0]['labels'][3]
    h=firstthree_list[j][0]['scores'][3]
    l_a.append(a)
    l_b.append(b)
    l_c.append(c)
    l_d.append(d)
    l_e.append(e)
    l_f.append(f)
    l_g.append(g)
    l_h.append(h)

# %%
fotth_title = {'first three':df.firstthree,'domain of title':df.dom,'label1':l_a,'score1':l_b,'label2':l_c,'score2':l_d,'label3':l_e,'score3':l_f,'label14':l_g,'score4':l_h}
dfotth_title = pd.DataFrame(fotth_title)

# %%
dfotth_title
# Out:
#                                           first three domain of title  \
# 0   A whopping majority of Turkish people do not t...          Others
# 1   A few days ago, PML-N President and Opposition...        Politics
# 2   French President Emmanuel Macron said Thursday...          Others
# 3   Former special assistant to prime minister (SA...           Crime
# 4   The rebels have now entered the town of Shire,...        Politics
# 5   The critically acclaimed Radio Television Hong...        Politics
# 6   On 26 September, the Pakistan Air Force (PAF) ...       Terrorism
# 7   On 05 November 2019, the Pakistan Navy (PN) an...          Others
# 8   The Pakistan Air Force conducted a command lev...          Others
# 9   In the new year, we hope that the US side coul...          Others
# 10  The relationship between China and the United ...        Politics
# 11  A group of top U.S. national security agencies...          Others
# 12  Following government cyber breaches, the Biden...        Politics
# 13   A top Air Force general wants to dispel the c...          Others
# 14  U.S. Special Operations Command created a task...          Others
# 15  The U.S. Army will soon make “information adva...          Others
# 16  Northrop Grumman uses its Highly Immersive Vir...           Crime
# 17  The performance of the Israeli Iron Dome air d...          Others
# 18  In a clear sign that China really is the Biden...          Others
#
#       label1    score1         label2    score2         label3    score3  \
# 0   Politics  0.348539         Others  0.265351          Crime  0.117254
# 1   Politics  0.499902         Others  0.217249          Crime  0.077203
# 2   Politics  0.410223         Others  0.251397          Crime  0.088166
# 3   Politics  0.445809         Others  0.182570          Crime  0.175356
# 4     Others  0.320779       Politics  0.262092          Crime  0.137293
# 5   Politics  0.288121         Others  0.264902  Entertainment  0.104567
# 6     Others  0.242767          Crime  0.168456       Politics  0.162538
# 7     Others  0.306092       Politics  0.186501          Crime  0.163276
# 8     Others  0.383898          Crime  0.147574       Politics  0.135494
# 9   Politics  0.303852         Others  0.275307          Crime  0.140180
# 10  Politics  0.349648         Others  0.280697          Crime  0.109064
# 11    Others  0.400851          Crime  0.156072  Entertainment  0.113851
# 12     Crime  0.256750         Others  0.216493       Politics  0.178519
# 13    Others  0.373519       Politics  0.136274          Crime  0.135683
# 14    Others  0.451950       Politics  0.145373          Crime  0.123840
# 15    Others  0.350513          Crime  0.173987       Politics  0.152330
# 16    Others  0.328727  Entertainment  0.178034          Crime  0.170823
# 17    Others  0.237383       Politics  0.213531          Crime  0.152514
# 18    Others  0.301207       Politics  0.209477          Crime  0.174503
#
#           label14    score4
# 0       Terrorism  0.089782
# 1       Terrorism  0.060433
# 2   Entertainment  0.071528
# 3   Entertainment  0.055141
# 4       Terrorism  0.120850
# 5           Crime  0.103804
# 6   Entertainment  0.120700
# 7          Sports  0.105150
# 8       Terrorism  0.098338
# 9          Sports  0.080287
# 10  Entertainment  0.086040
# 11       Politics  0.106720
# 12  Entertainment  0.098085
# 13  Entertainment  0.112418
# 14  Entertainment  0.091779
# 15         Sports  0.088240
# 16         Sports  0.110482
# 17      Terrorism  0.136442
# 18      Terrorism  0.090297

# %%
dftra['firstthree'] = l_a

# %%
dftra
# Out:
#         title  firstone  firsttwo firstthree
# 0      Others  Politics  Politics   Politics
# 1    Politics  Politics  Politics   Politics
# 2      Others  Politics  Politics   Politics
# 3       Crime     Crime    Others   Politics
# 4    Politics    Others    Others     Others
# 5    Politics    Others    Others   Politics
# 6   Terrorism    Others    Others     Others
# 7      Others    Others    Others     Others
# 8      Others    Others    Others     Others
# 9      Others  Politics  Politics   Politics
# 10   Politics  Politics  Politics   Politics
# 11     Others    Others    Others     Others
# 12   Politics    Others     Crime      Crime
# 13     Others    Others    Others     Others
# 14     Others    Others    Others     Others
# 15     Others    Others    Others     Others
# 16      Crime    Others    Others     Others
# 17     Others    Others    Others     Others
# 18     Others  Politics    Others     Others

# %%
dfotth_title.label1.value_counts()
# Out:
# Others      11
# Politics     7
# Crime        1
# Name: label1, dtype: int64

# %% [markdown]
# **first 250 words**

# %%
first250_list = []
for i in range(len(df.first250)):
  sequence = ["{s}".format(s=df.first250[i])]
  #candidate_labels = ["Crime", "Politics", "National", "Information Warfare","Threats","Cyber Security","Government","International"]
  candidate_labels = ["Crime", "Politics", "Terrorism", "Finance","Sports","Entertainment","Others"] 
  poping_sequence = zero_shot_classifier(sequence, candidate_labels,hypothesis_template=hypothesis_template, multi_label=False)
  first250_list.append(poping_sequence)
  #print(poping_sequence)

# %%
l_a=[]
l_b=[]
l_c=[]
l_d=[]
l_e=[]
l_f=[]
l_g=[]
l_h=[]
for j in range(len(df.first250)): 
    a=first250_list[j][0]['labels'][0]
    b=first250_list[j][0]['scores'][0]
    c=first250_list[j][0]['labels'][1]
    d=first250_list[j][0]['scores'][1]
    e=first250_list[j][0]['labels'][2]
    f=first250_list[j][0]['scores'][2]
    g=first250_list[j][0]['labels'][3]
    h=first250_list[j][0]['scores'][3]
    l_a.append(a)
    l_b.append(b)
    l_c.append(c)
    l_d.append(d)
    l_e.append(e)
    l_f.append(f)
    l_g.append(g)
    l_h.append(h)

# %%
fotth250_title = {'first 250 words ':df.first250,'domain of title':df.dom,'label1':l_a,'score1':l_b,'label2':l_c,'score2':l_d,'label3':l_e,'score3':l_f,'label14':l_g,'score4':l_h}
dfotth250_title = pd.DataFrame(fotth250_title)

# %%
dfotth250_title
# Out:
#                                      first 250 words  domain of title  \
# 0   A whopping majority of Turkish people do not t...          Others
# 1   A few days ago, PML-N President and Opposition...        Politics
# 2   French President Emmanuel Macron said Thursday...          Others
# 3   Former special assistant to prime minister (SA...           Crime
# 4   The rebels have now entered the town of Shire,...        Politics
# 5   The critically acclaimed Radio Television Hong...        Politics
# 6   On 26 September, the Pakistan Air Force (PAF) ...       Terrorism
# 7   On 05 November 2019, the Pakistan Navy (PN) an...          Others
# 8   Islamabad 29 November, 2019:- The Pakistan Air...          Others
# 9   In the new year, we hope that the US side coul...          Others
# 10  The relationship between China and the United ...        Politics
# 11  A group of top U.S. national security agencies...          Others
# 12  Following government cyber breaches, the Biden...        Politics
# 13  A top Air Force general wants to dispel the co...          Others
# 14  U.S. Special Operations Command created a task...          Others
# 15  The U.S. Army will soon make “information adva...          Others
# 16  Northrop Grumman uses its Highly Immersive Vir...           Crime
# 17  The performance of the Israeli Iron Dome air d...          Others
# 18  In a clear sign that China really is the Biden...          Others
#
#       label1    score1    label2    score2         label3    score3  \
# 0     Others  0.323867  Politics  0.301622          Crime  0.120674
# 1   Politics  0.519573    Others  0.227217          Crime  0.063254
# 2     Others  0.392874  Politics  0.282532      Terrorism  0.091050
# 3   Politics  0.446962    Others  0.191589          Crime  0.159609
# 4     Others  0.279352  Politics  0.239851          Crime  0.117800
# 5     Others  0.400524  Politics  0.286739          Crime  0.080410
# 6     Others  0.330417  Politics  0.156137          Crime  0.144029
# 7     Others  0.259059  Politics  0.193204          Crime  0.173643
# 8     Others  0.803345  Politics  0.040531  Entertainment  0.038098
# 9   Politics  0.303647    Others  0.259060          Crime  0.179338
# 10    Others  0.540206  Politics  0.252491          Crime  0.062443
# 11    Others  0.410623     Crime  0.184542       Politics  0.119463
# 12    Others  0.342128     Crime  0.211102       Politics  0.129067
# 13    Others  0.407836     Crime  0.156343       Politics  0.117550
# 14    Others  0.430473  Politics  0.147839          Crime  0.126888
# 15    Others  0.318529     Crime  0.205138       Politics  0.150073
# 16    Others  0.325068     Crime  0.177414  Entertainment  0.118329
# 17    Others  0.256249     Crime  0.190646       Politics  0.168931
# 18  Politics  0.294976    Others  0.186343          Crime  0.175603
#
#           label14    score4
# 0          Sports  0.076010
# 1   Entertainment  0.059026
# 2           Crime  0.080444
# 3          Sports  0.055376
# 4          Sports  0.100069
# 5   Entertainment  0.067516
# 6         Finance  0.108447
# 7          Sports  0.114337
# 8          Sports  0.036397
# 9          Sports  0.077353
# 10         Sports  0.042398
# 11         Sports  0.079201
# 12         Sports  0.090045
# 13  Entertainment  0.107571
# 14         Sports  0.087162
# 15  Entertainment  0.105469
# 16         Sports  0.118046
# 17      Terrorism  0.126911
# 18      Terrorism  0.098716

# %%
dftra['first250'] = l_a

# %%
dftra
# Out:
#         title  firstone  firsttwo firstthree  first250
# 0      Others  Politics  Politics   Politics    Others
# 1    Politics  Politics  Politics   Politics  Politics
# 2      Others  Politics  Politics   Politics    Others
# 3       Crime     Crime    Others   Politics  Politics
# 4    Politics    Others    Others     Others    Others
# 5    Politics    Others    Others   Politics    Others
# 6   Terrorism    Others    Others     Others    Others
# 7      Others    Others    Others     Others    Others
# 8      Others    Others    Others     Others    Others
# 9      Others  Politics  Politics   Politics  Politics
# 10   Politics  Politics  Politics   Politics    Others
# 11     Others    Others    Others     Others    Others
# 12   Politics    Others     Crime      Crime    Others
# 13     Others    Others    Others     Others    Others
# 14     Others    Others    Others     Others    Others
# 15     Others    Others    Others     Others    Others
# 16      Crime    Others    Others     Others    Others
# 17     Others    Others    Others     Others    Others
# 18     Others  Politics    Others     Others  Politics

# %%
dfotth250_title.label1.value_counts()
# Out:
# Others      15
# Politics     4
# Name: label1, dtype: int64

# %% [markdown]
# **last sentence**

# %%
lastone_list = []
for i in range(len(df.lastone)):
  sequence = ["{s}".format(s=df.lastone[i])]
  #candidate_labels = ["Crime", "Politics", "National", "Information Warfare","Threats","Cyber Security","Government","International"]
  candidate_labels = ["Crime", "Politics", "Terrorism", "Finance","Sports","Entertainment","Others"] 
  poping_sequence = zero_shot_classifier(sequence, candidate_labels,hypothesis_template=hypothesis_template, multi_label=False)
  lastone_list.append(poping_sequence)
  #print(poping_sequence)

# %%
l_a=[]
l_b=[]
l_c=[]
l_d=[]
l_e=[]
l_f=[]
l_g=[]
l_h=[]
for j in range(len(df.lastone)): 
    a=lastone_list[j][0]['labels'][0]
    b=lastone_list[j][0]['scores'][0]
    c=lastone_list[j][0]['labels'][1]
    d=lastone_list[j][0]['scores'][1]
    e=lastone_list[j][0]['labels'][2]
    f=lastone_list[j][0]['scores'][2]
    g=lastone_list[j][0]['labels'][3]
    h=lastone_list[j][0]['scores'][3]
    l_a.append(a)
    l_b.append(b)
    l_c.append(c)
    l_d.append(d)
    l_e.append(e)
    l_f.append(f)
    l_g.append(g)
    l_h.append(h)

# %%
las_title = {'last one sentence':df.lastone,'domain of title ':df.dom,'label1':l_a,'score1':l_b,'label2':l_c,'score2':l_d,'label3':l_e,'score3':l_f,'label14':l_g,'score4':l_h}
l_title = pd.DataFrame(las_title)

# %%
l_title
# Out:
#                                     last one sentence domain of title   \
# 0    The alliance is based on the core principle o...           Others
# 1    But he had to face embarrassment at the hands...         Politics
# 2    We must ensure that no misunderstanding comes...           Others
# 3   is ensured that the new alignment is free from...            Crime
# 4    The UN has said there was a situation of fami...         Politics
# 5   "2019 was a turning point and [the crackdown] ...         Politics
# 6   Tomislav Mesaric. â€œPride of Pakistanâ€. Air...        Terrorism
# 7    According to the Pakistan Ministry of Defence...           Others
# 8    If your company would like to request Quwa to...           Others
# 9   Despite challenges and difficulties, they will...           Others
# 10  The Chinese foreign minister urged to work tog...         Politics
# 11  These vulnerabilities could then later be expl...           Others
# 12  Mark Warner, D-Virginia, chairman of the Intel...         Politics
# 13  “We’ll need capabilities to streamline the spe...           Others
# 14   This is something that U.S. Cyber Command and...           Others
# 15  Given how quickly the information domain evolv...           Others
# 16  we have innovative applications of digital too...            Crime
# 17  The largest of the four categories is called “...           Others
# 18  With today’s directive, the task force is no m...           Others
#
#       label1    score1         label2    score2         label3    score3  \
# 0   Politics  0.351172          Crime  0.155962         Others  0.141093
# 1   Politics  0.263803  Entertainment  0.236709         Others  0.201515
# 2     Others  0.436294       Politics  0.147488          Crime  0.126267
# 3     Others  0.256874        Finance  0.255667       Politics  0.170635
# 4     Others  0.459572          Crime  0.152512       Politics  0.141769
# 5      Crime  0.254630         Others  0.242968       Politics  0.212247
# 6     Others  0.440223         Sports  0.152140  Entertainment  0.114559
# 7     Others  0.366564          Crime  0.173589       Politics  0.141830
# 8     Others  0.562959  Entertainment  0.124254        Finance  0.089717
# 9   Politics  0.511136         Others  0.204604          Crime  0.112542
# 10    Others  0.415156       Politics  0.270124          Crime  0.088270
# 11    Others  0.456282          Crime  0.189912  Entertainment  0.107003
# 12  Politics  0.288709         Others  0.275705          Crime  0.186799
# 13    Others  0.328190          Crime  0.181546       Politics  0.121388
# 14    Others  0.631976          Crime  0.124072       Politics  0.079795
# 15    Others  0.379727          Crime  0.188574       Politics  0.102306
# 16    Others  0.260407          Crime  0.170790  Entertainment  0.147975
# 17    Others  0.262176          Crime  0.234630       Politics  0.168455
# 18    Others  0.304548       Politics  0.233729          Crime  0.169121
#
#           label14    score4
# 0       Terrorism  0.115167
# 1           Crime  0.129474
# 2   Entertainment  0.086300
# 3           Crime  0.159086
# 4         Finance  0.085307
# 5   Entertainment  0.098938
# 6        Politics  0.108863
# 7       Terrorism  0.104843
# 8        Politics  0.071178
# 9         Finance  0.051625
# 10        Finance  0.065586
# 11        Finance  0.080302
# 12      Terrorism  0.119627
# 13  Entertainment  0.110781
# 14      Terrorism  0.054255
# 15         Sports  0.101882
# 16        Finance  0.126922
# 17        Finance  0.144742
# 18        Finance  0.095394

# %%
dftra['lastone'] = l_a

# %%
dftra
# Out:
#         title  firstone  firsttwo firstthree  first250   lastone
# 0      Others  Politics  Politics   Politics    Others  Politics
# 1    Politics  Politics  Politics   Politics  Politics  Politics
# 2      Others  Politics  Politics   Politics    Others    Others
# 3       Crime     Crime    Others   Politics  Politics    Others
# 4    Politics    Others    Others     Others    Others    Others
# 5    Politics    Others    Others   Politics    Others     Crime
# 6   Terrorism    Others    Others     Others    Others    Others
# 7      Others    Others    Others     Others    Others    Others
# 8      Others    Others    Others     Others    Others    Others
# 9      Others  Politics  Politics   Politics  Politics  Politics
# 10   Politics  Politics  Politics   Politics    Others    Others
# 11     Others    Others    Others     Others    Others    Others
# 12   Politics    Others     Crime      Crime    Others  Politics
# 13     Others    Others    Others     Others    Others    Others
# 14     Others    Others    Others     Others    Others    Others
# 15     Others    Others    Others     Others    Others    Others
# 16      Crime    Others    Others     Others    Others    Others
# 17     Others    Others    Others     Others    Others    Others
# 18     Others  Politics    Others     Others  Politics    Others

# %%
l_title.label1.value_counts()
# Out:
# Others      14
# Politics     4
# Crime        1
# Name: label1, dtype: int64

# %% [markdown]
# **last two sentence**

# %%
lasttwo_list = []
for i in range(len(df.lasttwo)):
  sequence = ["{s}".format(s=df.lasttwo[i])]
  #candidate_labels = ["Crime", "Politics", "National", "Information Warfare","Threats","Cyber Security","Government","International"]
  candidate_labels = ["Crime", "Politics", "Terrorism", "Finance","Sports","Entertainment","Others"] 
  poping_sequence = zero_shot_classifier(sequence, candidate_labels,hypothesis_template=hypothesis_template, multi_label=False)
  lasttwo_list.append(poping_sequence)
  #print(poping_sequence)

# %%
l_a=[]
l_b=[]
l_c=[]
l_d=[]
l_e=[]
l_f=[]
l_g=[]
l_h=[]
for j in range(len(df.lasttwo)): 
    a=lasttwo_list[j][0]['labels'][0]
    b=lasttwo_list[j][0]['scores'][0]
    c=lasttwo_list[j][0]['labels'][1]
    d=lasttwo_list[j][0]['scores'][1]
    e=lasttwo_list[j][0]['labels'][2]
    f=lasttwo_list[j][0]['scores'][2]
    g=lasttwo_list[j][0]['labels'][3]
    h=lasttwo_list[j][0]['scores'][3]
    l_a.append(a)
    l_b.append(b)
    l_c.append(c)
    l_d.append(d)
    l_e.append(e)
    l_f.append(f)
    l_g.append(g)
    l_h.append(h)

# %%
last_title = {'last two sentence':df.lasttwo,'domain of title':df.dom,'label1':l_a,'score1':l_b,'label2':l_c,'score2':l_d,'label3':l_e,'score3':l_f,'label14':l_g,'score4':l_h}
lto_title = pd.DataFrame(last_title)

# %%
lto_title
# Out:
#                                     last two sentence domain of title  \
# 0    Turkey is important for NATO, but NATO is als...          Others
# 1    As a matter of principle, Shehbaz Sharif’s in...        Politics
# 2    And they will remain so. We must ensure that ...          Others
# 3   Rawalpindi Commissioner Syed Gulzar Hussain Sh...           Crime
# 4   State department spokesperson Ned Price said t...        Politics
# 5   Analysts say the changes to RTHK are yet anoth...        Politics
# 6   The which will be the JF-17â€™s most extensive...       Terrorism
# 7   Having acquired long-range subsonic ASCMs, the...          Others
# 8    Quwa does not grant rights to reproduce or us...          Others
# 9   They will adopt a holistic approach to nationa...          Others
# 10  Oxen are known for their diligence and strengt...        Politics
# 11  Flaws or malware inserted early in the develop...          Others
# 12  Congress is going to have to step up and do mo...        Politics
# 13  Culture also must change to accept automation,...          Others
# 14  “This is not going to be episodic. This is som...          Others
# 15  The Army in 2017 released the to integrate cyb...          Others
# 16  What we have on the production line now are so...           Crime
# 17  In this brief video interview, Northrop Grumma...          Others
# 18  “The initiatives I am putting forward today ar...          Others
#
#       label1    score1         label2    score2         label3    score3  \
# 0     Others  0.364668       Politics  0.280769          Crime  0.100943
# 1   Politics  0.517151         Others  0.273480          Crime  0.059655
# 2     Others  0.371168       Politics  0.166309          Crime  0.143738
# 3     Others  0.304695       Politics  0.220590          Crime  0.145428
# 4     Others  0.374807          Crime  0.177796       Politics  0.175456
# 5   Politics  0.288848         Others  0.261720          Crime  0.135171
# 6     Others  0.284689       Politics  0.162862          Crime  0.159523
# 7     Others  0.277111       Politics  0.229003          Crime  0.153144
# 8     Others  0.501016  Entertainment  0.144351         Sports  0.087055
# 9   Politics  0.380251         Others  0.265258          Crime  0.131098
# 10    Others  0.304512       Politics  0.274673          Crime  0.126360
# 11    Others  0.337682          Crime  0.277947  Entertainment  0.101157
# 12    Others  0.247801          Crime  0.242108       Politics  0.232293
# 13    Others  0.389677          Crime  0.173114  Entertainment  0.124020
# 14    Others  0.498751          Crime  0.170679       Politics  0.095048
# 15    Others  0.385632          Crime  0.170452       Politics  0.109413
# 16    Others  0.334190          Crime  0.177504  Entertainment  0.127104
# 17     Crime  0.207963         Others  0.202723       Politics  0.174298
# 18    Others  0.270443       Politics  0.257888          Crime  0.156838
#
#           label14    score4
# 0       Terrorism  0.080036
# 1       Terrorism  0.044880
# 2   Entertainment  0.097754
# 3         Finance  0.105216
# 4       Terrorism  0.102110
# 5   Entertainment  0.102744
# 6   Entertainment  0.114837
# 7       Terrorism  0.115168
# 8         Finance  0.085638
# 9          Sports  0.073440
# 10         Sports  0.110190
# 11        Finance  0.087581
# 12  Entertainment  0.080163
# 13       Politics  0.104670
# 14      Terrorism  0.063587
# 15         Sports  0.101302
# 16       Politics  0.106942
# 17         Sports  0.125689
# 18        Finance  0.084240

# %%
dftra['lasttwo'] = l_a

# %%
dftra
# Out:
#         title  firstone  firsttwo firstthree  first250   lastone   lasttwo
# 0      Others  Politics  Politics   Politics    Others  Politics    Others
# 1    Politics  Politics  Politics   Politics  Politics  Politics  Politics
# 2      Others  Politics  Politics   Politics    Others    Others    Others
# 3       Crime     Crime    Others   Politics  Politics    Others    Others
# 4    Politics    Others    Others     Others    Others    Others    Others
# 5    Politics    Others    Others   Politics    Others     Crime  Politics
# 6   Terrorism    Others    Others     Others    Others    Others    Others
# 7      Others    Others    Others     Others    Others    Others    Others
# 8      Others    Others    Others     Others    Others    Others    Others
# 9      Others  Politics  Politics   Politics  Politics  Politics  Politics
# 10   Politics  Politics  Politics   Politics    Others    Others    Others
# 11     Others    Others    Others     Others    Others    Others    Others
# 12   Politics    Others     Crime      Crime    Others  Politics    Others
# 13     Others    Others    Others     Others    Others    Others    Others
# 14     Others    Others    Others     Others    Others    Others    Others
# 15     Others    Others    Others     Others    Others    Others    Others
# 16      Crime    Others    Others     Others    Others    Others    Others
# 17     Others    Others    Others     Others    Others    Others     Crime
# 18     Others  Politics    Others     Others  Politics    Others    Others

# %%
lto_title.label1.value_counts()
# Out:
# Others      15
# Politics     3
# Crime        1
# Name: label1, dtype: int64

# %% [markdown]
# **last three sentence**

# %%
lastthree_list = []
for i in range(len(df.lastthree)):
  sequence = ["{s}".format(s=df.lastthree[i])]
  #candidate_labels = ["Crime", "Politics", "National", "Information Warfare","Threats","Cyber Security","Government","International"]  
  candidate_labels = ["Crime", "Politics", "Terrorism", "Finance","Sports","Entertainment","Others"] 
  poping_sequence = zero_shot_classifier(sequence, candidate_labels,hypothesis_template=hypothesis_template, multi_label=False)
  lastthree_list.append(poping_sequence)
  #print(poping_sequence)

# %%
l_a=[]
l_b=[]
l_c=[]
l_d=[]
l_e=[]


l_f=[]
l_g=[]
l_h=[]
for j in range(len(df.lastthree)): 
    a=lastthree_list[j][0]['labels'][0]
    b=lastthree_list[j][0]['scores'][0]
    c=lastthree_list[j][0]['labels'][1]
    d=lastthree_list[j][0]['scores'][1]
    e=lastthree_list[j][0]['labels'][2]
    f=lastthree_list[j][0]['scores'][2]
    g=lastthree_list[j][0]['labels'][3]
    h=lastthree_list[j][0]['scores'][3]
    l_a.append(a)
    l_b.append(b)
    l_c.append(c)
    l_d.append(d)
    l_e.append(e)
    l_f.append(f)
    l_g.append(g)
    l_h.append(h)

# %%
lastthree_title = {'last three sentence':df.lastthree,'domain of title':df.dom,'label1':l_a,'score1':l_b,'label2':l_c,'score2':l_d,'label3':l_e,'score3':l_f,'label14':l_g,'score4':l_h}
ltoth_title = pd.DataFrame(lastthree_title)

# %%
ltoth_title
# Out:
#                                   last three sentence domain of title  \
# 0    Despite this fluctuating relationship, NATO c...          Others
# 1   At this juncture the question is not whether t...        Politics
# 2    During the visit, parth said Turkey and Franc...          Others
# 3    The Punjab government said that former commis...           Crime
# 4    On Tuesday, senior US state department offici...        Politics
# 5     "Many of them think that RTHK should not bit...        Politics
# 6   However, in the absence of a larger medium-to-...       Terrorism
# 7   One option could be to procure the SLR-66 from...          Others
# 8   Thus, Quwa does not accept responsibility or l...          Others
# 9   In the year to come, under the guidance of Xi ...          Others
# 10  He also expressed sincere appreciation to memb...        Politics
# 11  These components could contain malicious code ...          Others
# 12  This executive order is a good first step, but...        Politics
# 13  The Air Force will need support from industry ...          Others
# 14  How do we improve the further resilience of th...          Others
# 15  Minting the term in official doctrine will fil...          Others
# 16  The team is making terrific progress. I couldn...           Crime
# 17  This includes implementation of Joint All Doma...          Others
# 18  But they will also have a sharper influence on...          Others
#
#       label1    score1         label2    score2         label3    score3  \
# 0   Politics  0.330364         Others  0.255823          Crime  0.112336
# 1   Politics  0.532157         Others  0.223120          Crime  0.067673
# 2     Others  0.323342       Politics  0.287711          Crime  0.093826
# 3     Others  0.236161       Politics  0.227219          Crime  0.221441
# 4     Others  0.323048          Crime  0.201290       Politics  0.176803
# 5   Politics  0.296946         Others  0.257688          Crime  0.124011
# 6     Others  0.314751       Politics  0.160033  Entertainment  0.119926
# 7     Others  0.306779       Politics  0.183988          Crime  0.138058
# 8     Others  0.587243  Entertainment  0.089093        Finance  0.088992
# 9   Politics  0.437551         Others  0.181960          Crime  0.120692
# 10    Others  0.306875       Politics  0.270038          Crime  0.126575
# 11    Others  0.389946          Crime  0.281324  Entertainment  0.078665
# 12    Others  0.252040          Crime  0.241739       Politics  0.219516
# 13    Others  0.378556          Crime  0.161163  Entertainment  0.126603
# 14    Others  0.403563          Crime  0.215962       Politics  0.120482
# 15    Others  0.320270          Crime  0.195297       Politics  0.146549
# 16    Others  0.380537          Crime  0.167028  Entertainment  0.117138
# 17    Others  0.293115          Crime  0.193336       Politics  0.150915
# 18  Politics  0.288417         Others  0.272518          Crime  0.151816
#
#           label14    score4
# 0       Terrorism  0.087514
# 1       Terrorism  0.055155
# 2       Terrorism  0.080243
# 3         Finance  0.102330
# 4       Terrorism  0.101721
# 5   Entertainment  0.109000
# 6           Crime  0.119893
# 7       Terrorism  0.113330
# 8           Crime  0.070628
# 9          Sports  0.081081
# 10         Sports  0.098216
# 11        Finance  0.075927
# 12        Finance  0.077812
# 13       Politics  0.106220
# 14      Terrorism  0.081263
# 15         Sports  0.099644
# 16       Politics  0.097733
# 17         Sports  0.098602
# 18        Finance  0.077223

# %%
dftra['lastthree'] = l_a

# %%
dftra
# Out:
#         title  firstone  firsttwo firstthree  first250   lastone   lasttwo  \
# 0      Others  Politics  Politics   Politics    Others  Politics    Others
# 1    Politics  Politics  Politics   Politics  Politics  Politics  Politics
# 2      Others  Politics  Politics   Politics    Others    Others    Others
# 3       Crime     Crime    Others   Politics  Politics    Others    Others
# 4    Politics    Others    Others     Others    Others    Others    Others
# 5    Politics    Others    Others   Politics    Others     Crime  Politics
# 6   Terrorism    Others    Others     Others    Others    Others    Others
# 7      Others    Others    Others     Others    Others    Others    Others
# 8      Others    Others    Others     Others    Others    Others    Others
# 9      Others  Politics  Politics   Politics  Politics  Politics  Politics
# 10   Politics  Politics  Politics   Politics    Others    Others    Others
# 11     Others    Others    Others     Others    Others    Others    Others
# 12   Politics    Others     Crime      Crime    Others  Politics    Others
# 13     Others    Others    Others     Others    Others    Others    Others
# 14     Others    Others    Others     Others    Others    Others    Others
# 15     Others    Others    Others     Others    Others    Others    Others
# 16      Crime    Others    Others     Others    Others    Others    Others
# 17     Others    Others    Others     Others    Others    Others     Crime
# 18     Others  Politics    Others     Others  Politics    Others    Others
#
#    lastthree
# 0   Politics
# 1   Politics
# 2     Others
# 3     Others
# 4     Others
# 5   Politics
# 6     Others
# 7     Others
# 8     Others
# 9   Politics
# 10    Others
# 11    Others
# 12    Others
# 13    Others
# 14    Others
# 15    Others
# 16    Others
# 17    Others
# 18  Politics

# %%
ltoth_title.label1.value_counts()
# Out:
# Others      14
# Politics     5
# Name: label1, dtype: int64

# %% [markdown]
# **last 250 sentence**

# %%
last250_list = []
for i in range(len(df.last250)):
  sequence = ["{s}".format(s=df.last250[i])]
  #candidate_labels = ["Crime", "Politics", "National", "Information Warfare","Threats","Cyber Security","Government","International"]  
  candidate_labels = ["Crime", "Politics", "Terrorism", "Finance","Sports","Entertainment","Others"] 
  poping_sequence = zero_shot_classifier(sequence, candidate_labels,hypothesis_template=hypothesis_template, multi_label=False)
  last250_list.append(poping_sequence)
  #print(poping_sequence)

# %%
l_a=[]
l_b=[]
l_c=[]
l_d=[]
l_e=[]
l_f=[]
l_g=[]
l_h=[]
for j in range(len(df.last250)): 
    a=last250_list[j][0]['labels'][0]
    b=last250_list[j][0]['scores'][0]
    c=last250_list[j][0]['labels'][1]
    d=last250_list[j][0]['scores'][1]
    e=last250_list[j][0]['labels'][2]
    f=last250_list[j][0]['scores'][2]
    g=last250_list[j][0]['labels'][3]
    h=last250_list[j][0]['scores'][3]
    l_a.append(a)
    l_b.append(b)
    l_c.append(c)
    l_d.append(d)
    l_e.append(e)
    l_f.append(f)
    l_g.append(g)
    l_h.append(h)

# %%
last250_title = {'last 250':df.last250,'domain of title':df.dom,'label1':l_a,'score1':l_b,'label2':l_c,'score2':l_d,'label3':l_e,'score3':l_f,'label14':l_g,'score4':l_h}
l250_title = pd.DataFrame(last250_title)

# %%
l250_title
# Out:
#                                              last 250 domain of title  \
# 0    and millions of Turkish citizens. Some 250 pe...          Others
# 1   message that Shehbaz Sharif’s efforts to persu...        Politics
# 2   death" of NATO, where Turkey is a key member  ...          Others
# 3   also summoned the files of the Ministry of Ove...           Crime
# 4    The status of Eritrean troops remains unclear...        Politics
# 5   And unlike his predecessors, Mr Li has not acc...        Politics
# 6   The JF-17 reportedly has an airframe life of 3...       Terrorism
# 7   The PN added that the â€œoperationalization of...          Others
# 8   Islamabad 29 November, 2019:- The Pakistan Air...          Others
# 9   original aspiration and spared no effort to st...          Others
# 10  global economic recovery and development. He a...        Politics
# 11  to exploit for valuable information and intell...          Others
# 12  lesser network problem, the order creates a pl...        Politics
# 13  ”The misconception that adversaries’ priority ...          Others
# 14  1st Special Forces Command built an specifical...          Others
# 15   Hersey describes five pillars of information ...          Others
# 16  A single major discovery in early development,...           Crime
# 17  Since then, Iron Dome has played an instrument...          Others
# 18  The concept, as readers know, is the capstone ...          Others
#
#       label1    score1    label2    score2         label3    score3  \
# 0   Politics  0.328500    Others  0.248443          Crime  0.134588
# 1   Politics  0.422895    Others  0.331134          Crime  0.072730
# 2     Others  0.353524  Politics  0.260381      Terrorism  0.098728
# 3   Politics  0.271801    Others  0.235750          Crime  0.235433
# 4     Others  0.306879  Politics  0.241709          Crime  0.143656
# 5   Politics  0.299541    Others  0.265998          Crime  0.118692
# 6     Others  0.295374  Politics  0.145063          Crime  0.122904
# 7     Others  0.279053     Crime  0.173253       Politics  0.169055
# 8     Others  0.803345  Politics  0.040531  Entertainment  0.038098
# 9   Politics  0.409572    Others  0.227410          Crime  0.126977
# 10    Others  0.410974  Politics  0.197358        Finance  0.098228
# 11    Others  0.309006     Crime  0.207681       Politics  0.133833
# 12    Others  0.459475     Crime  0.200412       Politics  0.114608
# 13    Others  0.400915     Crime  0.172269       Politics  0.106814
# 14    Others  0.358675     Crime  0.214358        Finance  0.126627
# 15    Others  0.329226     Crime  0.166107       Politics  0.143576
# 16    Others  0.284802     Crime  0.187344        Finance  0.129380
# 17    Others  0.286669  Politics  0.200388          Crime  0.133932
# 18    Others  0.334750  Politics  0.214164          Crime  0.176310
#
#           label14    score4
# 0       Terrorism  0.123101
# 1          Sports  0.048285
# 2           Crime  0.095364
# 3          Sports  0.068446
# 4       Terrorism  0.084766
# 5   Entertainment  0.092232
# 6   Entertainment  0.118756
# 7          Sports  0.123191
# 8          Sports  0.036397
# 9          Sports  0.077061
# 10          Crime  0.095762
# 11        Finance  0.129440
# 12  Entertainment  0.062042
# 13  Entertainment  0.104113
# 14       Politics  0.102484
# 15  Entertainment  0.113201
# 16  Entertainment  0.122176
# 17      Terrorism  0.111778
# 18         Sports  0.074827

# %%
dftra['last250'] = l_a

# %%
dftra
# Out:
#         title  firstone  firsttwo firstthree  first250   lastone   lasttwo  \
# 0      Others  Politics  Politics   Politics    Others  Politics    Others
# 1    Politics  Politics  Politics   Politics  Politics  Politics  Politics
# 2      Others  Politics  Politics   Politics    Others    Others    Others
# 3       Crime     Crime    Others   Politics  Politics    Others    Others
# 4    Politics    Others    Others     Others    Others    Others    Others
# 5    Politics    Others    Others   Politics    Others     Crime  Politics
# 6   Terrorism    Others    Others     Others    Others    Others    Others
# 7      Others    Others    Others     Others    Others    Others    Others
# 8      Others    Others    Others     Others    Others    Others    Others
# 9      Others  Politics  Politics   Politics  Politics  Politics  Politics
# 10   Politics  Politics  Politics   Politics    Others    Others    Others
# 11     Others    Others    Others     Others    Others    Others    Others
# 12   Politics    Others     Crime      Crime    Others  Politics    Others
# 13     Others    Others    Others     Others    Others    Others    Others
# 14     Others    Others    Others     Others    Others    Others    Others
# 15     Others    Others    Others     Others    Others    Others    Others
# 16      Crime    Others    Others     Others    Others    Others    Others
# 17     Others    Others    Others     Others    Others    Others     Crime
# 18     Others  Politics    Others     Others  Politics    Others    Others
#
#    lastthree   last250
# 0   Politics  Politics
# 1   Politics  Politics
# 2     Others    Others
# 3     Others  Politics
# 4     Others    Others
# 5   Politics  Politics
# 6     Others    Others
# 7     Others    Others
# 8     Others    Others
# 9   Politics  Politics
# 10    Others    Others
# 11    Others    Others
# 12    Others    Others
# 13    Others    Others
# 14    Others    Others
# 15    Others    Others
# 16    Others    Others
# 17    Others    Others
# 18  Politics    Others

# %%
l250_title.label1.value_counts()
# Out:
# Others      14
# Politics     5
# Name: label1, dtype: int64

# %% [markdown]
# **one combined**

# %%
onecom_list = []
for i in range(len(df.onecom)):
  sequence = ["{s}".format(s=df.onecom[i])]
  #candidate_labels = ["Crime", "Politics", "National", "Information Warfare","Threats","Cyber Security","Government","International"]  
  candidate_labels = ["Crime", "Politics", "Terrorism", "Finance","Sports","Entertainment","Others"] 
  poping_sequence = zero_shot_classifier(sequence, candidate_labels,hypothesis_template=hypothesis_template, multi_label=False)
  onecom_list.append(poping_sequence)
  #print(poping_sequence)

# %%
l_a=[]
l_b=[]
l_c=[]
l_d=[]
l_e=[]
l_f=[]
l_g=[]
l_h=[]
for j in range(len(df.onecom)): 
    a=onecom_list[j][0]['labels'][0]
    b=onecom_list[j][0]['scores'][0]
    c=onecom_list[j][0]['labels'][1]
    d=onecom_list[j][0]['scores'][1]
    e=onecom_list[j][0]['labels'][2]
    f=onecom_list[j][0]['scores'][2]
    g=onecom_list[j][0]['labels'][3]
    h=onecom_list[j][0]['scores'][3]
    l_a.append(a)
    l_b.append(b)
    l_c.append(c)
    l_d.append(d)
    l_e.append(e)
    l_f.append(f)
    l_g.append(g)
    l_h.append(h)

# %%
oc_title = {'one combined ':df.onecom,'domain of title':df.dom,'label1':l_a,'score1':l_b,'label2':l_c,'score2':l_d,'label3':l_e,'score3':l_f,'label14':l_g,'score4':l_h}
onec_title = pd.DataFrame(oc_title)

# %%
onec_title
# Out:
#                                         one combined  domain of title  \
# 0   A whopping majority of Turkish people do not t...          Others
# 1   A few days ago, PML-N President and Opposition...        Politics
# 2   French President Emmanuel Macron said Thursday...          Others
# 3   Former special assistant to prime minister (SA...           Crime
# 4   The rebels have now entered the town of Shire,...        Politics
# 5   The critically acclaimed Radio Television Hong...        Politics
# 6   On 26 September, the Pakistan Air Force (PAF) ...       Terrorism
# 7   On 05 November 2019, the Pakistan Navy (PN) an...          Others
# 8   The Pakistan Air Force conducted a command lev...          Others
# 9   In the new year, we hope that the US side coul...          Others
# 10  The relationship between China and the United ...        Politics
# 11  A group of top U.S. national security agencies...          Others
# 12  Following government cyber breaches, the Biden...        Politics
# 13  A top Air Force general wants to dispel the co...          Others
# 14  U.S. Special Operations Command created a task...          Others
# 15  The U.S. Army will soon make “information adva...          Others
# 16  Northrop Grumman uses its Highly Immersive Vir...           Crime
# 17   The performance of the Israeli Iron Dome air ...          Others
# 18   In a clear sign that China really is the Bide...          Others
#
#       label1    score1    label2    score2         label3    score3  \
# 0   Politics  0.310727    Others  0.218634          Crime  0.137015
# 1   Politics  0.552173    Others  0.182160          Crime  0.065338
# 2   Politics  0.384182    Others  0.295000          Crime  0.087505
# 3   Politics  0.301559     Crime  0.272360         Others  0.208176
# 4     Others  0.340549  Politics  0.200366          Crime  0.152811
# 5     Others  0.323226  Politics  0.224398          Crime  0.149697
# 6     Others  0.197255  Politics  0.172347         Sports  0.152664
# 7     Others  0.339646     Crime  0.175271       Politics  0.155854
# 8     Others  0.485656     Crime  0.102580       Politics  0.098344
# 9   Politics  0.344772    Others  0.271772          Crime  0.139482
# 10  Politics  0.295079    Others  0.266610          Crime  0.135582
# 11    Others  0.390893     Crime  0.168132       Politics  0.120873
# 12     Crime  0.260205    Others  0.250520       Politics  0.214152
# 13    Others  0.366265     Crime  0.158501       Politics  0.136156
# 14    Others  0.329235     Crime  0.211102       Politics  0.139044
# 15    Others  0.240679  Politics  0.195368          Crime  0.187737
# 16    Others  0.324865     Crime  0.156616  Entertainment  0.154795
# 17    Others  0.296469     Crime  0.180943       Politics  0.163249
# 18  Politics  0.287911    Others  0.205693          Crime  0.153691
#
#           label14    score4
# 0       Terrorism  0.116405
# 1   Entertainment  0.060636
# 2   Entertainment  0.066038
# 3       Terrorism  0.060448
# 4       Terrorism  0.110100
# 5   Entertainment  0.101083
# 6   Entertainment  0.145406
# 7       Terrorism  0.132631
# 8         Finance  0.093309
# 9   Entertainment  0.064783
# 10  Entertainment  0.082564
# 11         Sports  0.089839
# 12        Finance  0.073446
# 13  Entertainment  0.121065
# 14      Terrorism  0.101137
# 15         Sports  0.120776
# 16       Politics  0.113026
# 17      Terrorism  0.103580
# 18        Finance  0.138220

# %%
dftra['onecom'] = l_a

# %%
dftra
# Out:
#         title  firstone  firsttwo firstthree  first250   lastone   lasttwo  \
# 0      Others  Politics  Politics   Politics    Others  Politics    Others
# 1    Politics  Politics  Politics   Politics  Politics  Politics  Politics
# 2      Others  Politics  Politics   Politics    Others    Others    Others
# 3       Crime     Crime    Others   Politics  Politics    Others    Others
# 4    Politics    Others    Others     Others    Others    Others    Others
# 5    Politics    Others    Others   Politics    Others     Crime  Politics
# 6   Terrorism    Others    Others     Others    Others    Others    Others
# 7      Others    Others    Others     Others    Others    Others    Others
# 8      Others    Others    Others     Others    Others    Others    Others
# 9      Others  Politics  Politics   Politics  Politics  Politics  Politics
# 10   Politics  Politics  Politics   Politics    Others    Others    Others
# 11     Others    Others    Others     Others    Others    Others    Others
# 12   Politics    Others     Crime      Crime    Others  Politics    Others
# 13     Others    Others    Others     Others    Others    Others    Others
# 14     Others    Others    Others     Others    Others    Others    Others
# 15     Others    Others    Others     Others    Others    Others    Others
# 16      Crime    Others    Others     Others    Others    Others    Others
# 17     Others    Others    Others     Others    Others    Others     Crime
# 18     Others  Politics    Others     Others  Politics    Others    Others
#
#    lastthree   last250    onecom
# 0   Politics  Politics  Politics
# 1   Politics  Politics  Politics
# 2     Others    Others  Politics
# 3     Others  Politics  Politics
# 4     Others    Others    Others
# 5   Politics  Politics    Others
# 6     Others    Others    Others
# 7     Others    Others    Others
# 8     Others    Others    Others
# 9   Politics  Politics  Politics
# 10    Others    Others  Politics
# 11    Others    Others    Others
# 12    Others    Others     Crime
# 13    Others    Others    Others
# 14    Others    Others    Others
# 15    Others    Others    Others
# 16    Others    Others    Others
# 17    Others    Others    Others
# 18  Politics    Others  Politics

# %%
onec_title.label1.value_counts()
# Out:
# Others      11
# Politics     7
# Crime        1
# Name: label1, dtype: int64

# %% [markdown]
# **two combined**

# %%
twocom_list = []
for i in range(len(df.twocom)):
  sequence = ["{s}".format(s=df.twocom[i])]
  #candidate_labels = ["Crime", "Politics", "National", "Information Warfare","Threats","Cyber Security","Government","International"]  
  candidate_labels = ["Crime", "Politics", "Terrorism", "Finance","Sports","Entertainment","Others"] 
  poping_sequence = zero_shot_classifier(sequence, candidate_labels,hypothesis_template=hypothesis_template, multi_label=False)
  twocom_list.append(poping_sequence)
  #print(poping_sequence)

# %%
l_a=[]
l_b=[]
l_c=[]
l_d=[]
l_e=[]
l_f=[]
l_g=[]
l_h=[]
for j in range(len(df.twocom)): 
    a=twocom_list[j][0]['labels'][0]
    b=twocom_list[j][0]['scores'][0]
    c=twocom_list[j][0]['labels'][1]
    d=twocom_list[j][0]['scores'][1]
    e=twocom_list[j][0]['labels'][2]
    f=twocom_list[j][0]['scores'][2]
    g=twocom_list[j][0]['labels'][3]
    h=twocom_list[j][0]['scores'][3]
    l_a.append(a)
    l_b.append(b)
    l_c.append(c)
    l_d.append(d)
    l_e.append(e)
    l_f.append(f)
    l_g.append(g)
    l_h.append(h)

# %%
tc_title = {'two combined ':df.twocom,'domain of title':df.dom,'label1':l_a,'score1':l_b,'label2':l_c,'score2':l_d,'label3':l_e,'score3':l_f,'label14':l_g,'score4':l_h}
twoc_title = pd.DataFrame(tc_title)

# %%
twoc_title
# Out:
#                                         two combined  domain of title  \
# 0   A whopping majority of Turkish people do not t...          Others
# 1   A few days ago, PML-N President and Opposition...        Politics
# 2   French President Emmanuel Macron said Thursday...          Others
# 3   Former special assistant to prime minister (SA...           Crime
# 4   The rebels have now entered the town of Shire,...        Politics
# 5   The critically acclaimed Radio Television Hong...        Politics
# 6   On 26 September, the Pakistan Air Force (PAF) ...       Terrorism
# 7   On 05 November 2019, the Pakistan Navy (PN) an...          Others
# 8   The Pakistan Air Force conducted a command lev...          Others
# 9   In the new year, we hope that the US side coul...          Others
# 10  The relationship between China and the United ...        Politics
# 11  A group of top U.S. national security agencies...          Others
# 12  Following government cyber breaches, the Biden...        Politics
# 13  A top Air Force general wants to dispel the co...          Others
# 14  U.S. Special Operations Command created a task...          Others
# 15  The U.S. Army will soon make “information adva...          Others
# 16  Northrop Grumman uses its Highly Immersive Vir...           Crime
# 17  The performance of the Israeli Iron Dome air d...          Others
# 18  In a clear sign that China really is the Biden...          Others
#
#       label1    score1    label2    score2         label3    score3  \
# 0   Politics  0.366108    Others  0.226386          Crime  0.111205
# 1   Politics  0.510035    Others  0.253484          Crime  0.060457
# 2     Others  0.359610  Politics  0.315477          Crime  0.088228
# 3   Politics  0.268241    Others  0.224081          Crime  0.218184
# 4     Others  0.311257  Politics  0.196089          Crime  0.180285
# 5     Others  0.335480  Politics  0.257093          Crime  0.101235
# 6     Others  0.256470  Politics  0.152910          Crime  0.147480
# 7     Others  0.242647  Politics  0.206194          Crime  0.165473
# 8     Others  0.607499  Politics  0.086827  Entertainment  0.077989
# 9   Politics  0.353721    Others  0.264324          Crime  0.133171
# 10  Politics  0.294464    Others  0.257146          Crime  0.126684
# 11    Others  0.343866     Crime  0.196763  Entertainment  0.119266
# 12     Crime  0.264390    Others  0.219427       Politics  0.184906
# 13    Others  0.422881     Crime  0.149655       Politics  0.113466
# 14    Others  0.381193     Crime  0.168535       Politics  0.144060
# 15    Others  0.276415     Crime  0.191855       Politics  0.155214
# 16    Others  0.363017     Crime  0.194603  Entertainment  0.118641
# 17    Others  0.246035  Politics  0.176477          Crime  0.176255
# 18    Others  0.280506  Politics  0.211487          Crime  0.180332
#
#           label14    score4
# 0       Terrorism  0.099169
# 1   Entertainment  0.055461
# 2   Entertainment  0.074976
# 3         Finance  0.082820
# 4       Terrorism  0.116691
# 5   Entertainment  0.098852
# 6          Sports  0.132134
# 7       Terrorism  0.115597
# 8          Sports  0.070407
# 9          Sports  0.070731
# 10         Sports  0.098753
# 11       Politics  0.100013
# 12  Entertainment  0.102773
# 13  Entertainment  0.108735
# 14      Terrorism  0.091547
# 15         Sports  0.111127
# 16         Sports  0.101376
# 17      Terrorism  0.110713
# 18        Finance  0.085298

# %%
dftra["twocom"] = l_a

# %%
dftra
# Out:
#         title  firstone  firsttwo firstthree  first250   lastone   lasttwo  \
# 0      Others  Politics  Politics   Politics    Others  Politics    Others
# 1    Politics  Politics  Politics   Politics  Politics  Politics  Politics
# 2      Others  Politics  Politics   Politics    Others    Others    Others
# 3       Crime     Crime    Others   Politics  Politics    Others    Others
# 4    Politics    Others    Others     Others    Others    Others    Others
# 5    Politics    Others    Others   Politics    Others     Crime  Politics
# 6   Terrorism    Others    Others     Others    Others    Others    Others
# 7      Others    Others    Others     Others    Others    Others    Others
# 8      Others    Others    Others     Others    Others    Others    Others
# 9      Others  Politics  Politics   Politics  Politics  Politics  Politics
# 10   Politics  Politics  Politics   Politics    Others    Others    Others
# 11     Others    Others    Others     Others    Others    Others    Others
# 12   Politics    Others     Crime      Crime    Others  Politics    Others
# 13     Others    Others    Others     Others    Others    Others    Others
# 14     Others    Others    Others     Others    Others    Others    Others
# 15     Others    Others    Others     Others    Others    Others    Others
# 16      Crime    Others    Others     Others    Others    Others    Others
# 17     Others    Others    Others     Others    Others    Others     Crime
# 18     Others  Politics    Others     Others  Politics    Others    Others
#
#    lastthree   last250    onecom    twocom
# 0   Politics  Politics  Politics  Politics
# 1   Politics  Politics  Politics  Politics
# 2     Others    Others  Politics    Others
# 3     Others  Politics  Politics  Politics
# 4     Others    Others    Others    Others
# 5   Politics  Politics    Others    Others
# 6     Others    Others    Others    Others
# 7     Others    Others    Others    Others
# 8     Others    Others    Others    Others
# 9   Politics  Politics  Politics  Politics
# 10    Others    Others  Politics  Politics
# 11    Others    Others    Others    Others
# 12    Others    Others     Crime     Crime
# 13    Others    Others    Others    Others
# 14    Others    Others    Others    Others
# 15    Others    Others    Others    Others
# 16    Others    Others    Others    Others
# 17    Others    Others    Others    Others
# 18  Politics    Others  Politics    Others

# %%
twoc_title.label1.value_counts()
# Out:
# Others      13
# Politics     5
# Crime        1
# Name: label1, dtype: int64

# %% [markdown]
# **Three combined**

# %%
threecom_list = []
for i in range(len(df.threecom)):
  sequence = ["{s}".format(s=df.threecom[i])]
  #candidate_labels = ["Crime", "Politics", "National", "Information Warfare","Threats","Cyber Security","Government","International"]  
  candidate_labels = ["Crime", "Politics", "Terrorism", "Finance","Sports","Entertainment","Others"] 
  poping_sequence = zero_shot_classifier(sequence, candidate_labels,hypothesis_template=hypothesis_template, multi_label=False)
  threecom_list.append(poping_sequence)
  #print(poping_sequence)

# %%
l_a=[]
l_b=[]
l_c=[]
l_d=[]
l_e=[]
l_f=[]
l_g=[]
l_h=[]
for j in range(len(df.threecom)): 
    a=threecom_list[j][0]['labels'][0]
    b=threecom_list[j][0]['scores'][0]
    c=threecom_list[j][0]['labels'][1]
    d=threecom_list[j][0]['scores'][1]
    e=threecom_list[j][0]['labels'][2]
    f=threecom_list[j][0]['scores'][2]
    g=threecom_list[j][0]['labels'][3]
    h=threecom_list[j][0]['scores'][3]
    l_a.append(a)
    l_b.append(b)
    l_c.append(c)
    l_d.append(d)
    l_e.append(e)
    l_f.append(f)
    l_g.append(g)
    l_h.append(h)

# %%
thr_title = {'three combined':df.threecom,'domain of title':df.dom,'label1':l_a,'score1':l_b,'label2':l_c,'score2':l_d,'label3':l_e,'score3':l_f,'label14':l_g,'score4':l_h}
tree_title = pd.DataFrame(thr_title)

# %%
tree_title
# Out:
#                                        three combined domain of title  \
# 0   A whopping majority of Turkish people do not t...          Others
# 1   A few days ago, PML-N President and Opposition...        Politics
# 2   French President Emmanuel Macron said Thursday...          Others
# 3   Former special assistant to prime minister (SA...           Crime
# 4   The rebels have now entered the town of Shire,...        Politics
# 5   The critically acclaimed Radio Television Hong...        Politics
# 6   On 26 September, the Pakistan Air Force (PAF) ...       Terrorism
# 7   On 05 November 2019, the Pakistan Navy (PN) an...          Others
# 8   Thus, Quwa does not accept responsibility or l...          Others
# 9   In the new year, we hope that the US side coul...          Others
# 10  The relationship between China and the United ...        Politics
# 11  A group of top U.S. national security agencies...          Others
# 12  Following government cyber breaches, the Biden...        Politics
# 13   A top Air Force general wants to dispel the c...          Others
# 14  U.S. Special Operations Command created a task...          Others
# 15  The U.S. Army will soon make “information adva...          Others
# 16  Northrop Grumman uses its Highly Immersive Vir...           Crime
# 17  The performance of the Israeli Iron Dome air d...          Others
# 18  In a clear sign that China really is the Biden...          Others
#
#       label1    score1         label2    score2         label3    score3  \
# 0   Politics  0.341425         Others  0.244631          Crime  0.106503
# 1   Politics  0.499074         Others  0.243847          Crime  0.072299
# 2     Others  0.336067       Politics  0.304250      Terrorism  0.085101
# 3   Politics  0.357617          Crime  0.210935         Others  0.157712
# 4     Others  0.326479       Politics  0.200870          Crime  0.179605
# 5   Politics  0.383736         Others  0.242443          Crime  0.106841
# 6     Others  0.262788       Politics  0.182682          Crime  0.142742
# 7     Others  0.256400       Politics  0.191731          Crime  0.170352
# 8     Others  0.574730  Entertainment  0.115912        Finance  0.095572
# 9   Politics  0.493250         Others  0.200683          Crime  0.115932
# 10    Others  0.338138       Politics  0.302376          Crime  0.110148
# 11    Others  0.372628          Crime  0.194630       Politics  0.108379
# 12    Others  0.307673          Crime  0.209133       Politics  0.181404
# 13    Others  0.429047          Crime  0.149561  Entertainment  0.106643
# 14    Others  0.454494          Crime  0.147345       Politics  0.126902
# 15    Others  0.363520          Crime  0.177987       Politics  0.127460
# 16    Others  0.349658          Crime  0.224020  Entertainment  0.105487
# 17    Others  0.236203          Crime  0.189153       Politics  0.186733
# 18    Others  0.342048       Politics  0.215811          Crime  0.162781
#
#           label14    score4
# 0       Terrorism  0.102577
# 1       Terrorism  0.054311
# 2           Crime  0.084675
# 3         Finance  0.072230
# 4       Terrorism  0.116332
# 5         Finance  0.075280
# 6          Sports  0.118841
# 7          Sports  0.110431
# 8           Crime  0.085052
# 9          Sports  0.058890
# 10         Sports  0.072192
# 11  Entertainment  0.098245
# 12  Entertainment  0.093675
# 13       Politics  0.105925
# 14  Entertainment  0.080095
# 15  Entertainment  0.103298
# 16         Sports  0.097998
# 17      Terrorism  0.140015
# 18      Terrorism  0.078496

# %%
dftra["threecom"] = l_a

# %%
dftra
# Out:
#         title  firstone  firsttwo firstthree  first250   lastone   lasttwo  \
# 0      Others  Politics  Politics   Politics    Others  Politics    Others
# 1    Politics  Politics  Politics   Politics  Politics  Politics  Politics
# 2      Others  Politics  Politics   Politics    Others    Others    Others
# 3       Crime     Crime    Others   Politics  Politics    Others    Others
# 4    Politics    Others    Others     Others    Others    Others    Others
# 5    Politics    Others    Others   Politics    Others     Crime  Politics
# 6   Terrorism    Others    Others     Others    Others    Others    Others
# 7      Others    Others    Others     Others    Others    Others    Others
# 8      Others    Others    Others     Others    Others    Others    Others
# 9      Others  Politics  Politics   Politics  Politics  Politics  Politics
# 10   Politics  Politics  Politics   Politics    Others    Others    Others
# 11     Others    Others    Others     Others    Others    Others    Others
# 12   Politics    Others     Crime      Crime    Others  Politics    Others
# 13     Others    Others    Others     Others    Others    Others    Others
# 14     Others    Others    Others     Others    Others    Others    Others
# 15     Others    Others    Others     Others    Others    Others    Others
# 16      Crime    Others    Others     Others    Others    Others    Others
# 17     Others    Others    Others     Others    Others    Others     Crime
# 18     Others  Politics    Others     Others  Politics    Others    Others
#
#    lastthree   last250    onecom    twocom  threecom
# 0   Politics  Politics  Politics  Politics  Politics
# 1   Politics  Politics  Politics  Politics  Politics
# 2     Others    Others  Politics    Others    Others
# 3     Others  Politics  Politics  Politics  Politics
# 4     Others    Others    Others    Others    Others
# 5   Politics  Politics    Others    Others  Politics
# 6     Others    Others    Others    Others    Others
# 7     Others    Others    Others    Others    Others
# 8     Others    Others    Others    Others    Others
# 9   Politics  Politics  Politics  Politics  Politics
# 10    Others    Others  Politics  Politics    Others
# 11    Others    Others    Others    Others    Others
# 12    Others    Others     Crime     Crime    Others
# 13    Others    Others    Others    Others    Others
# 14    Others    Others    Others    Others    Others
# 15    Others    Others    Others    Others    Others
# 16    Others    Others    Others    Others    Others
# 17    Others    Others    Others    Others    Others
# 18  Politics    Others  Politics    Others    Others

# %%
#candidate_labels = ["Crime", "Politics", "National", "Information Warfare","Threats","Cyber Security","Government","International"]
#candidate_labels = ["Crime", "Politics", "Terrorism", "Finance","Sports","Entertainment","Others"]

# %%
tree_title.label1.value_counts()
# Out:
# Others      14
# Politics     5
# Name: label1, dtype: int64

# %% [markdown]
# **combined all**

# %%
com250_list = []
for i in range(len(df.com250)):
  sequence = ["{s}".format(s=df.com250[i])]
  #candidate_labels = ["Crime", "Politics", "National", "Information Warfare","Threats","Cyber Security","Government","International"]  
  candidate_labels = ["Crime", "Politics", "Terrorism", "Finance","Sports","Entertainment","Others"] 
  poping_sequence = zero_shot_classifier(sequence, candidate_labels,hypothesis_template=hypothesis_template, multi_label=False)
  com250_list.append(poping_sequence)
  #print(poping_sequence)

# %%
l_a=[]
l_b=[]
l_c=[]
l_d=[]
l_e=[]
l_f=[]
l_g=[]
l_h=[]
for j in range(len(df.com250)): 
    a=com250_list[j][0]['labels'][0]
    b=com250_list[j][0]['scores'][0]
    c=com250_list[j][0]['labels'][1]
    d=com250_list[j][0]['scores'][1]
    e=com250_list[j][0]['labels'][2]
    f=com250_list[j][0]['scores'][2]
    g=com250_list[j][0]['labels'][3]
    h=com250_list[j][0]['scores'][3]
    l_a.append(a)
    l_b.append(b)
    l_c.append(c)
    l_d.append(d)
    l_e.append(e)
    l_f.append(f)
    l_g.append(g)
    l_h.append(h)

# %%
comm250_title = {'title':df.com250,'domain of title':df.dom,'label1':l_a,'score1':l_b,'label2':l_c,'score2':l_d,'label3':l_e,'score3':l_f,'label14':l_g,'score4':l_h}
commm_title = pd.DataFrame(comm250_title)

# %%
commm_title
# Out:
#                                                 title domain of title  \
# 0   A whopping majority of Turkish people do not t...          Others
# 1   A few days ago, PML-N President and Opposition...        Politics
# 2   French President Emmanuel Macron said Thursday...          Others
# 3   Former special assistant to prime minister (SA...           Crime
# 4   The rebels have now entered the town of Shire,...        Politics
# 5   The critically acclaimed Radio Television Hong...        Politics
# 6   On 26 September, the Pakistan Air Force (PAF) ...       Terrorism
# 7   On 05 November 2019, the Pakistan Navy (PN) an...          Others
# 8   Islamabad 29 November, 2019:- The Pakistan Air...          Others
# 9   In the new year, we hope that the US side coul...          Others
# 10  The relationship between China and the United ...        Politics
# 11  A group of top U.S. national security agencies...          Others
# 12  Following government cyber breaches, the Biden...        Politics
# 13  A top Air Force general wants to dispel the co...          Others
# 14  U.S. Special Operations Command created a task...          Others
# 15  The U.S. Army will soon make “information adva...          Others
# 16  Northrop Grumman uses its Highly Immersive Vir...           Crime
# 17  The performance of the Israeli Iron Dome air d...          Others
# 18  In a clear sign that China really is the Biden...          Others
#
#       label1    score1         label2    score2         label3    score3  \
# 0   Politics  0.314423         Others  0.300524          Crime  0.100222
# 1     Others  0.492714       Politics  0.285752          Crime  0.064024
# 2     Others  0.414190       Politics  0.334855      Terrorism  0.062860
# 3     Others  0.293351       Politics  0.292447          Crime  0.186162
# 4     Others  0.459927       Politics  0.223218          Crime  0.124000
# 5     Others  0.487471       Politics  0.274615          Crime  0.080120
# 6     Others  0.296043  Entertainment  0.179531         Sports  0.131556
# 7     Others  0.307407       Politics  0.195758          Crime  0.147935
# 8     Others  0.803345       Politics  0.040531  Entertainment  0.038098
# 9   Politics  0.475401         Others  0.305892          Crime  0.059969
# 10    Others  0.465276       Politics  0.271864          Crime  0.079039
# 11    Others  0.352530          Crime  0.178205       Politics  0.134199
# 12    Others  0.519035          Crime  0.175476       Politics  0.113643
# 13    Others  0.491970          Crime  0.167788  Entertainment  0.103705
# 14    Others  0.521122          Crime  0.167326       Politics  0.111151
# 15    Others  0.476026          Crime  0.145740       Politics  0.098233
# 16    Others  0.345671          Crime  0.198426         Sports  0.110411
# 17    Others  0.239655       Politics  0.209215      Terrorism  0.152602
# 18    Others  0.363387       Politics  0.248061          Crime  0.128543
#
#           label14    score4
# 0       Terrorism  0.082855
# 1         Finance  0.047160
# 2          Sports  0.058970
# 3          Sports  0.064863
# 4          Sports  0.070090
# 5          Sports  0.049067
# 6           Crime  0.125951
# 7       Terrorism  0.109073
# 8          Sports  0.036397
# 9          Sports  0.051064
# 10         Sports  0.070238
# 11         Sports  0.097069
# 12         Sports  0.064911
# 13       Politics  0.073722
# 14  Entertainment  0.056883
# 15  Entertainment  0.082449
# 16       Politics  0.088144
# 17          Crime  0.128304
# 18        Finance  0.080524

# %%
dftra["allcom"] = l_a

# %%
dftra
# Out:
#         title  firstone  firsttwo firstthree  first250   lastone   lasttwo  \
# 0      Others  Politics  Politics   Politics    Others  Politics    Others
# 1    Politics  Politics  Politics   Politics  Politics  Politics  Politics
# 2      Others  Politics  Politics   Politics    Others    Others    Others
# 3       Crime     Crime    Others   Politics  Politics    Others    Others
# 4    Politics    Others    Others     Others    Others    Others    Others
# 5    Politics    Others    Others   Politics    Others     Crime  Politics
# 6   Terrorism    Others    Others     Others    Others    Others    Others
# 7      Others    Others    Others     Others    Others    Others    Others
# 8      Others    Others    Others     Others    Others    Others    Others
# 9      Others  Politics  Politics   Politics  Politics  Politics  Politics
# 10   Politics  Politics  Politics   Politics    Others    Others    Others
# 11     Others    Others    Others     Others    Others    Others    Others
# 12   Politics    Others     Crime      Crime    Others  Politics    Others
# 13     Others    Others    Others     Others    Others    Others    Others
# 14     Others    Others    Others     Others    Others    Others    Others
# 15     Others    Others    Others     Others    Others    Others    Others
# 16      Crime    Others    Others     Others    Others    Others    Others
# 17     Others    Others    Others     Others    Others    Others     Crime
# 18     Others  Politics    Others     Others  Politics    Others    Others
#
#    lastthree   last250    onecom    twocom  threecom    allcom
# 0   Politics  Politics  Politics  Politics  Politics  Politics
# 1   Politics  Politics  Politics  Politics  Politics    Others
# 2     Others    Others  Politics    Others    Others    Others
# 3     Others  Politics  Politics  Politics  Politics    Others
# 4     Others    Others    Others    Others    Others    Others
# 5   Politics  Politics    Others    Others  Politics    Others
# 6     Others    Others    Others    Others    Others    Others
# 7     Others    Others    Others    Others    Others    Others
# 8     Others    Others    Others    Others    Others    Others
# 9   Politics  Politics  Politics  Politics  Politics  Politics
# 10    Others    Others  Politics  Politics    Others    Others
# 11    Others    Others    Others    Others    Others    Others
# 12    Others    Others     Crime     Crime    Others    Others
# 13    Others    Others    Others    Others    Others    Others
# 14    Others    Others    Others    Others    Others    Others
# 15    Others    Others    Others    Others    Others    Others
# 16    Others    Others    Others    Others    Others    Others
# 17    Others    Others    Others    Others    Others    Others
# 18  Politics    Others  Politics    Others    Others    Others

# %%
commm_title.label1.value_counts()
# Out:
# Others      17
# Politics     2
# Name: label1, dtype: int64

# %% [markdown]
# **comparison**

# %%
c1=0
c2=0
c3=0
c4=0
c5=0
c6=0
c7=0
c8=0
c9=0
c10=0
c11=0
c12=0
for i in range(19):
  if dftra['title'][i] == dftra['firstone'][i]:
    c1 = c1 + 1
  if dftra['title'][i] == dftra['firsttwo'][i]:
    c2 = c2 + 1
  if dftra['title'][i] == dftra['firstthree'][i]:
    c3 = c3 + 1
  if dftra['title'][i] == dftra['first250'][i]:
    c4 = c4 + 1
  if dftra['title'][i] == dftra['lastone'][i]:
    c5 = c5 + 1
  if dftra['title'][i] == dftra['lasttwo'][i]:
    c6 = c6 + 1
  if dftra['title'][i] == dftra['lastthree'][i]:
    c7 = c7 + 1
  if dftra['title'][i] == dftra['last250'][i]:
    c8 = c8 + 1
  if dftra['title'][i] == dftra['onecom'][i]:
    c9 = c9 + 1
  if dftra['title'][i] == dftra['twocom'][i]:
    c10 = c10 + 1
  if dftra['title'][i] == dftra['threecom'][i]:
    c11 = c11 + 1
  if dftra['title'][i] == dftra['allcom'][i]:
    c12 = c12 + 1
print(c1)
print(c2)
print(c3)
print(c4)
print(c5)
print(c6)
print(c7)
print(c8)
print(c9)
print(c10)
print(c11)
print(c12)
# Out:
# 10
# 10
# 11
# 10
# 11
# 11
# 10
# 11
# 9
# 11
# 11
# 9

# %%
y_true=dftra['title'].tolist()
y_true
# Out:
# ['Others',
#  'Politics',
#  'Others',
#  'Crime',
#  'Politics',
#  'Politics',
#  'Terrorism',
#  'Others',
#  'Others',
#  'Others',
#  'Politics',
#  'Others',
#  'Politics',
#  'Others',
#  'Others',
#  'Others',
#  'Crime',
#  'Others',
#  'Others']

# %%
y_pre=dftra.transpose().values.tolist()

# %%
from sklearn.metrics import classification_report
for i in range(13):  
  print(classification_report(y_true, y_pre[i]))
# Out:
#               precision    recall  f1-score   support
#
#        Crime       1.00      1.00      1.00         2
#       Others       1.00      1.00      1.00        11
#     Politics       1.00      1.00      1.00         5
#    Terrorism       1.00      1.00      1.00         1
#
#     accuracy                           1.00        19
#    macro avg       1.00      1.00      1.00        19
# weighted avg       1.00      1.00      1.00        19
#
#               precision    recall  f1-score   support
#
#        Crime       1.00      0.50      0.67         2
#       Others       0.58      0.64      0.61        11
#     Politics       0.33      0.40      0.36         5
#    Terrorism       0.00      0.00      0.00         1
#
#     accuracy                           0.53        19
#    macro avg       0.48      0.38      0.41        19
# weighted avg       0.53      0.53      0.52        19
#
#               precision    recall  f1-score   support
#
#        Crime       0.00      0.00      0.00         2
#       Others       0.62      0.73      0.67        11
#     Politics       0.40      0.40      0.40         5
#    Terrorism       0.00      0.00      0.00         1
#
#     accuracy                           0.53        19
#    macro avg       0.25      0.28      0.27        19
# weighted avg       0.46      0.53      0.49        19
#
#               precision    recall  f1-score   support
#
#        Crime       0.00      0.00      0.00         2
#       Others       0.73      0.73      0.73        11
#     Politics       0.43      0.60      0.50         5
#    Terrorism       0.00      0.00      0.00         1
#
#     accuracy                           0.58        19
#    macro avg       0.29      0.33      0.31        19
# weighted avg       0.53      0.58      0.55        19
#
#               precision    recall  f1-score   support
#
#        Crime       0.00      0.00      0.00         2
#       Others       0.60      0.82      0.69        11
#     Politics       0.25      0.20      0.22         5
#    Terrorism       0.00      0.00      0.00         1
#
#     accuracy                           0.53        19
#    macro avg       0.21      0.25      0.23        19
# weighted avg       0.41      0.53      0.46        19
#
#               precision    recall  f1-score   support
#
#        Crime       0.00      0.00      0.00         2
#       Others       0.64      0.82      0.72        11
#     Politics       0.50      0.40      0.44         5
#    Terrorism       0.00      0.00      0.00         1
#
#     accuracy                           0.58        19
#    macro avg       0.29      0.30      0.29        19
# weighted avg       0.50      0.58      0.53        19
#
#               precision    recall  f1-score   support
#
#        Crime       0.00      0.00      0.00         2
#       Others       0.60      0.82      0.69        11
#     Politics       0.67      0.40      0.50         5
#    Terrorism       0.00      0.00      0.00         1
#
#     accuracy                           0.58        19
#    macro avg       0.32      0.30      0.30        19
# weighted avg       0.52      0.58      0.53        19
#
#               precision    recall  f1-score   support
#
#        Crime       0.00      0.00      0.00         2
#       Others       0.57      0.73      0.64        11
#     Politics       0.40      0.40      0.40         5
#    Terrorism       0.00      0.00      0.00         1
#
#     accuracy                           0.53        19
#    macro avg       0.24      0.28      0.26        19
# weighted avg       0.44      0.53      0.48        19
#
#               precision    recall  f1-score   support
#
#        Crime       0.00      0.00      0.00         2
#       Others       0.64      0.82      0.72        11
#     Politics       0.40      0.40      0.40         5
#    Terrorism       0.00      0.00      0.00         1
#
#     accuracy                           0.58        19
#    macro avg       0.26      0.30      0.28        19
# weighted avg       0.48      0.58      0.52        19
#
#               precision    recall  f1-score   support
#
#        Crime       0.00      0.00      0.00         2
#       Others       0.64      0.64      0.64        11
#     Politics       0.29      0.40      0.33         5
#    Terrorism       0.00      0.00      0.00         1
#
#     accuracy                           0.47        19
#    macro avg       0.23      0.26      0.24        19
# weighted avg       0.44      0.47      0.46        19
#
#               precision    recall  f1-score   support
#
#        Crime       0.00      0.00      0.00         2
#       Others       0.69      0.82      0.75        11
#     Politics       0.40      0.40      0.40         5
#    Terrorism       0.00      0.00      0.00         1
#
#     accuracy                           0.58        19
#    macro avg       0.27      0.30      0.29        19
# weighted avg       0.51      0.58      0.54        19
#
#               precision    recall  f1-score   support
#
#        Crime       0.00      0.00      0.00         2
#       Others       0.64      0.82      0.72        11
#     Politics       0.40      0.40      0.40         5
#    Terrorism       0.00      0.00      0.00         1
#
#     accuracy                           0.58        19
#    macro avg       0.26      0.30      0.28        19
# weighted avg       0.48      0.58      0.52        19
#
#               precision    recall  f1-score   support
#
#        Crime       0.00      0.00      0.00         2
#       Others       0.53      0.82      0.64        11
#     Politics       0.00      0.00      0.00         5
#    Terrorism       0.00      0.00      0.00         1
#
#     accuracy                           0.47        19
#    macro avg       0.13      0.20      0.16        19
# weighted avg       0.31      0.47      0.37        19
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
